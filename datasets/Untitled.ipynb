# %%
import unicodedata
from typing import Callable, Generator, Any
import json
from unidecode import unidecode
import csv
from collections import Counter

# %%
def memoize(f: Callable) -> Callable:
    """
    memoization decorator for a function taking ONLY a single argument
    src: http://code.activestate.com/recipes/578231-probably-the-fastest-memoization-decorator-in-the-/
    """

    class MemoDict(dict):
        def __missing__(self, key):
            ret = self[key] = f(key)
            return ret

    return MemoDict().__getitem__

@memoize
def is_word_char(char: str) -> bool:
    return unicodedata.category(char) in {'Lu', 'Ll', 'Lt', 'Lm', 'Lo',  # letters
                                          # 'Nd', 'Nl', 'No',  # numbers
                                          'Mn', 'Mc', 'Me',  # diacritics, etc
                                          # 'Co',  # private use char class
                                          }

def words(text: str) -> Generator[str, Any, None]:
    word_buffer = []
    for char in text:
        # char is part of word
        if is_word_char(char):
            word_buffer.append(char)

        # char is non-text AND buffer is text
        elif word_buffer:
            yield f''.join(word_buffer)#.casefold()
            word_buffer = []

    # yield remainder
    if word_buffer:
        yield f''.join(word_buffer)#.casefold()

# %%
rows = []
with open('MASTER.LINGUISTIC.1GRAM.big.csv', 'rt' ,encoding='utf8', newline='') as f:
    c = csv.reader(f)
    for i, row in enumerate(c):
        if (i + 1) % 1000000 == 0:
            print(i + 1)
        if row[0] == 'MALAY':
            rows.append(row)
# Out:
# 1000000
# 2000000
# 3000000
# 4000000
# 5000000
# 6000000
# 7000000
# 8000000
# 9000000
# 10000000
# 11000000
# 12000000
# 13000000
# 14000000
# 15000000
# 16000000
# 17000000
# 18000000
# 19000000
# 20000000
# 21000000
# 22000000
# 23000000
# 24000000
# 25000000
# 26000000
# 27000000
# 28000000
# 29000000
# 30000000
# 31000000
# 32000000
# 33000000
# 34000000
# 35000000
# 36000000
# 37000000
# 38000000
# 39000000
# 40000000
# 41000000
# 42000000
# 43000000
# 44000000
# 45000000
# 46000000
# 47000000
# 48000000
# 49000000
# 50000000
# 51000000
# 52000000
# 53000000
# 54000000
# 55000000
# 56000000
# 57000000
# 58000000
# 59000000
# 60000000
# 61000000
# 62000000
# 63000000
# 64000000
# 65000000
# 66000000
# 67000000
# 68000000
# 69000000
# 70000000
# 71000000
# 72000000
# 73000000
# 74000000
# 75000000
# 76000000
# 77000000
# 78000000
# 79000000
# 80000000
# 81000000
# 82000000
# 83000000
# 84000000
# 85000000
# 86000000
# 87000000
# 88000000
# 89000000
# 90000000
# 91000000
# 92000000
# 93000000
# 94000000
# 95000000
# 96000000
# 97000000
# 98000000
# 99000000
# 100000000
# 101000000
# 102000000
# 103000000
# 104000000
# 105000000
# 106000000
# 107000000
# 108000000
# 109000000
# 110000000
# 111000000
# 112000000
# 113000000
# 114000000
# 115000000
# 116000000
# 117000000
# 118000000
# 119000000
# 120000000
# 121000000
# 122000000
# 123000000
# 124000000

# %%
word_counts = Counter()
for row in rows:
    for word in words(row[1]):
        word_counts[word.casefold()] += int(row[2])

# %%
word_counts.most_common(1000)
# Out:
# [('rm', 1874016),
#  ('to', 1575740),
#  ('in', 1485760),
#  ('for', 1364739),
#  ('di', 1178209),
#  ('the', 1115668),
#  ('of', 1088133),
#  ('s', 1050269),
#  ('sqm', 1022913),
#  ('sqft', 1022892),
#  ('properties', 976728),
#  ('malaysia', 919802),
#  ('more', 693704),
#  ('yang', 659794),
#  ('ini', 635270),
#  ('video', 631991),
#  ('news', 563769),
#  ('dengan', 508396),
#  ('a', 498495),
#  ('new', 477752),
#  ('dan', 462913),
#  ('untuk', 458248),
#  ('on', 454915),
#  ('ke', 432370),
#  ('berita', 427828),
#  ('and', 425206),
#  ('no', 422817),
#  ('tak', 414164),
#  ('rent', 408566),
#  ('dalam', 389925),
#  ('najib', 385717),
#  ('anak', 362569),
#  ('tidak', 354724),
#  ('is', 352756),
#  ('sale', 341295),
#  ('mahathir', 339233),
#  ('dunia', 326064),
#  ('lifestyle', 324680),
#  ('umno', 316934),
#  ('with', 300981),
#  ('tahun', 298081),
#  ('sukan', 292616),
#  ('negara', 291113),
#  ('pas', 277138),
#  ('jadi', 275003),
#  ('tv', 273781),
#  ('buat', 268337),
#  ('nasional', 261815),
#  ('saya', 261464),
#  ('rtb', 261208),
#  ('as', 256333),
#  ('m', 253828),
#  ('football', 253651),
#  ('home', 252373),
#  ('world', 251297),
#  ('at', 251054),
#  ('read', 245292),
#  ('us', 245171),
#  ('dr', 242053),
#  ('archives', 240225),
#  ('terkini', 239025),
#  ('hari', 232002),
#  ('says', 227379),
#  ('property', 227262),
#  ('be', 226092),
#  ('akan', 225498),
#  ('johor', 215602),
#  ('pada', 213014),
#  ('trending', 211518),
#  ('anwar', 211300),
#  ('lagi', 209326),
#  ('you', 209238),
#  ('not', 207374),
#  ('lalu', 206732),
#  ('kl', 202656),
#  ('kami', 200022),
#  ('jam', 198049),
#  ('entertainment', 197622),
#  ('lebih', 196917),
#  ('boleh', 196523),
#  ('isu', 196461),
#  ('utama', 195099),
#  ('nak', 191906),
#  ('orang', 191204),
#  ('it', 191095),
#  ('korang', 186482),
#  ('raja', 184775),
#  ('anda', 183868),
#  ('all', 182414),
#  ('pru', 182380),
#  ('hiburan', 182349),
#  ('ada', 181250),
#  ('mark', 180995),
#  ('by', 180758),
#  ('lelaki', 179276),
#  ('wanita', 178762),
#  ('perlu', 178241),
#  ('dari', 176530),
#  ('leo', 176261),
#  ('after', 176179),
#  ('about', 174982),
#  ('will', 174709),
#  ('my', 173521),
#  ('sabah', 173366),
#  ('raya', 172328),
#  ('mt', 171346),
#  ('utusan', 169125),
#  ('up', 167182),
#  ('polis', 166364),
#  ('kepada', 166105),
#  ('may', 164912),
#  ('facebook', 164345),
#  ('politik', 162933),
#  ('t', 160443),
#  ('ministry', 159944),
#  ('policy', 159208),
#  ('kini', 157863),
#  ('sarawak', 156957),
#  ('out', 156328),
#  ('from', 155456),
#  ('dua', 154964),
#  ('pm', 154046),
#  ('bukan', 153577),
#  ('watch', 152801),
#  ('kelantan', 152666),
#  ('selangor', 152417),
#  ('rakyat', 151860),
#  ('presiden', 151046),
#  ('jpg', 151044),
#  ('islam', 149627),
#  ('jangan', 147851),
#  ('badminton', 146107),
#  ('april', 144903),
#  ('hidup', 144696),
#  ('videos', 143986),
#  ('bn', 143156),
#  ('webmaster', 143138),
#  ('china', 142766),
#  ('rumah', 142380),
#  ('baru', 141586),
#  ('over', 141480),
#  ('perak', 140651),
#  ('pilihan', 140146),
#  ('bakal', 140026),
#  ('tweet', 139367),
#  ('ph', 138413),
#  ('i', 138137),
#  ('malay', 137525),
#  ('sports', 137287),
#  ('business', 135904),
#  ('kata', 135074),
#  ('guide', 134946),
#  ('his', 134781),
#  ('what', 134242),
#  ('petra', 131800),
#  ('pahang', 131405),
#  ('privacy', 130723),
#  ('netizen', 130685),
#  ('negeri', 130074),
#  ('melayu', 128752),
#  ('main', 128380),
#  ('mahu', 128293),
#  ('kedah', 128010),
#  ('november', 127643),
#  ('popular', 127483),
#  ('komentar', 126891),
#  ('december', 125744),
#  ('selepas', 125730),
#  ('rencana', 125521),
#  ('kerajaan', 125337),
#  ('foto', 125301),
#  ('selanjutnya', 125233),
#  ('march', 125206),
#  ('kongsi', 124072),
#  ('any', 123987),
#  ('kita', 123950),
#  ('online', 123477),
#  ('penang', 123400),
#  ('terengganu', 123211),
#  ('isteri', 123110),
#  ('media', 122985),
#  ('june', 121928),
#  ('january', 121651),
#  ('september', 121648),
#  ('instagram', 120766),
#  ('july', 120741),
#  ('bekas', 120640),
#  ('baharu', 120031),
#  ('malaysian', 119382),
#  ('tun', 119376),
#  ('bh', 119161),
#  ('twitter', 119086),
#  ('this', 119038),
#  ('lain', 118538),
#  ('february', 118523),
#  ('gambar', 118348),
#  ('bootstrap', 117722),
#  ('maut', 117684),
#  ('kanak', 117646),
#  ('ni', 117645),
#  ('edisi', 117349),
#  ('slideshow', 116312),
#  ('max', 116182),
#  ('now', 114828),
#  ('your', 114745),
#  ('sea', 114393),
#  ('august', 114283),
#  ('ibu', 113768),
#  ('pakatan', 112690),
#  ('kuala', 112578),
#  ('are', 111740),
#  ('terima', 111404),
#  ('filem', 110869),
#  ('october', 110648),
#  ('bersama', 110282),
#  ('man', 110246),
#  ('azmin', 110033),
#  ('juta', 109292),
#  ('air', 108848),
#  ('pelajar', 108131),
#  ('tennis', 107932),
#  ('who', 106955),
#  ('e', 106587),
#  ('pertama', 106556),
#  ('min', 106355),
#  ('agama', 105877),
#  ('next', 105782),
#  ('apa', 105441),
#  ('kereta', 104812),
#  ('top', 104467),
#  ('here', 104370),
#  ('why', 103479),
#  ('tiada', 102953),
#  ('naik', 102943),
#  ('latest', 102458),
#  ('global', 102116),
#  ('lumpur', 102013),
#  ('live', 101574),
#  ('bila', 101113),
#  ('k', 99341),
#  ('games', 97806),
#  ('politics', 97623),
#  ('indonesia', 97393),
#  ('contact', 97229),
#  ('one', 97177),
#  ('paling', 97003),
#  ('kerana', 96787),
#  ('melaka', 96553),
#  ('list', 96506),
#  ('bisnes', 96460),
#  ('beri', 96100),
#  ('tapi', 95886),
#  ('bulan', 95829),
#  ('harga', 95540),
#  ('year', 95455),
#  ('jenayah', 95428),
#  ('sebab', 95181),
#  ('we', 94758),
#  ('bantu', 94412),
#  ('kamarudin', 94311),
#  ('luar', 94284),
#  ('tolak', 94100),
#  ('gaya', 93965),
#  ('guna', 93956),
#  ('health', 93894),
#  ('android', 93714),
#  ('but', 93562),
#  ('teknologi', 93456),
#  ('suami', 92826),
#  ('tiga', 92821),
#  ('pkr', 92462),
#  ('or', 92415),
#  ('sinar', 92372),
#  ('dap', 92264),
#  ('sekolah', 91163),
#  ('al', 91038),
#  ('can', 90963),
#  ('squash', 90736),
#  ('kes', 90163),
#  ('asia', 89830),
#  ('eng', 89557),
#  ('sembilan', 89333),
#  ('guan', 89261),
#  ('masa', 88761),
#  ('mdb', 87879),
#  ('share', 87562),
#  ('komen', 86900),
#  ('diri', 86490),
#  ('budaya', 86462),
#  ('was', 86391),
#  ('kolumnis', 86327),
#  ('dapat', 86134),
#  ('parlimen', 85886),
#  ('mahkamah', 85878),
#  ('dah', 85347),
#  ('perlis', 85327),
#  ('if', 85013),
#  ('hati', 84926),
#  ('viral', 84614),
#  ('putrajaya', 84578),
#  ('state', 84374),
#  ('harakah', 84260),
#  ('project', 84170),
#  ('tips', 83944),
#  ('jom', 83918),
#  ('harapan', 83639),
#  ('kosmo', 83434),
#  ('prk', 83169),
#  ('baik', 83120),
#  ('service', 82917),
#  ('alam', 82885),
#  ('formula', 82417),
#  ('lihat', 82020),
#  ('department', 81785),
#  ('bola', 81671),
#  ('commercial', 81322),
#  ('makan', 81171),
#  ('old', 80650),
#  ('power', 80410),
#  ('google', 80019),
#  ('cara', 79715),
#  ('sultan', 79331),
#  ('hanya', 79329),
#  ('bagi', 79290),
#  ('general', 79278),
#  ('menteri', 79086),
#  ('station', 79025),
#  ('keluarga', 78591),
#  ('selamat', 78567),
#  ('propertyguru', 78533),
#  ('muda', 78199),
#  ('rd', 78168),
#  ('masih', 78111),
#  ('go', 77879),
#  ('low', 77279),
#  ('ramai', 77079),
#  ('log', 77001),
#  ('has', 76651),
#  ('semua', 76294),
#  ('land', 76139),
#  ('sudah', 76110),
#  ('dia', 76104),
#  ('macam', 75944),
#  ('mana', 75648),
#  ('amanz', 75453),
#  ('buying', 75294),
#  ('kena', 75222),
#  ('tahu', 74965),
#  ('ago', 74961),
#  ('meninggal', 74928),
#  ('view', 74259),
#  ('rahman', 74248),
#  ('kesihatan', 74232),
#  ('how', 74040),
#  ('bisik', 73746),
#  ('terbaik', 73736),
#  ('siapa', 73487),
#  ('tinggalkan', 73025),
#  ('radio', 72991),
#  ('follow', 72926),
#  ('against', 72655),
#  ('ahli', 72590),
#  ('warga', 72253),
#  ('majlis', 72233),
#  ('semula', 71854),
#  ('commentaries', 71818),
#  ('email', 71611),
#  ('nigel', 71417),
#  ('hot', 71404),
#  ('dusanjh', 71391),
#  ('kalau', 71120),
#  ('drama', 71103),
#  ('kenapa', 71076),
#  ('vs', 70822),
#  ('kali', 70711),
#  ('exclusive', 70475),
#  ('he', 70450),
#  ('into', 70359),
#  ('like', 70218),
#  ('featured', 70027),
#  ('zahid', 69875),
#  ('huawei', 69450),
#  ('tawaran', 69445),
#  ('komuniti', 68945),
#  ('youtube', 68844),
#  ('piala', 68662),
#  ('peminat', 68625),
#  ('semasa', 68595),
#  ('terms', 68305),
#  ('sini', 68282),
#  ('sepak', 68059),
#  ('david', 67934),
#  ('juara', 67915),
#  ('minister', 67346),
#  ('hubungi', 67108),
#  ('x', 66894),
#  ('singapore', 66680),
#  ('off', 66533),
#  ('satu', 66389),
#  ('comments', 65805),
#  ('gadis', 65740),
#  ('jaya', 65611),
#  ('kisah', 65545),
#  ('pendidikan', 65530),
#  ('selebihnya', 65410),
#  ('sex', 65392),
#  ('sungai', 65212),
#  ('syarat', 65208),
#  ('krishnan', 65051),
#  ('use', 64982),
#  ('atau', 64948),
#  ('ios', 64942),
#  ('sebagai', 64923),
#  ('time', 64907),
#  ('opinion', 64705),
#  ('most', 64664),
#  ('our', 64466),
#  ('gowri', 64402),
#  ('bahasa', 64126),
#  ('first', 64072),
#  ('minion', 63949),
#  ('turn', 63796),
#  ('selebriti', 63731),
#  ('pernah', 63704),
#  ('pun', 63510),
#  ('their', 63364),
#  ('india', 63253),
#  ('ekonomi', 63184),
#  ('terus', 63146),
#  ('pimpinan', 63089),
#  ('seni', 63018),
#  ('should', 62910),
#  ('antara', 62898),
#  ('depan', 62796),
#  ('headline', 62718),
#  ('gallery', 62526),
#  ('ditahan', 62293),
#  ('cuba', 62285),
#  ('rasa', 62223),
#  ('niaga', 62173),
#  ('sedia', 61970),
#  ('golf', 61873),
#  ('jika', 61857),
#  ('azwa', 61658),
#  ('trump', 61539),
#  ('calon', 61507),
#  ('holds', 60928),
#  ('mudah', 60600),
#  ('mata', 60499),
#  ('umum', 60424),
#  ('login', 60390),
#  ('sertai', 60353),
#  ('datuk', 60242),
#  ('v', 60006),
#  ('mati', 59918),
#  ('khas', 59837),
#  ('sendiri', 59747),
#  ('daripada', 59515),
#  ('bersatu', 59464),
#  ('barred', 59397),
#  ('stop', 59349),
#  ('ahmad', 59166),
#  ('beli', 59141),
#  ('ramadan', 58878),
#  ('within', 58758),
#  ('have', 58538),
#  ('minta', 58504),
#  ('u', 58497),
#  ('sign', 57765),
#  ('wang', 57655),
#  ('travel', 57569),
#  ('jho', 57336),
#  ('bandar', 57331),
#  ('mb', 57189),
#  ('mengenai', 57148),
#  ('liverpool', 56947),
#  ('sains', 56911),
#  ('brunei', 56881),
#  ('gara', 56570),
#  ('kahwin', 56528),
#  ('university', 56462),
#  ('houses', 56418),
#  ('report', 56352),
#  ('pro', 56166),
#  ('kembali', 56086),
#  ('seri', 56002),
#  ('nur', 55945),
#  ('pemain', 55746),
#  ('corridors', 55713),
#  ('other', 55553),
#  ('besar', 55497),
#  ('didakwa', 55456),
#  ('mangsa', 55339),
#  ('data', 55269),
#  ('agong', 55255),
#  ('mat', 55198),
#  ('aziz', 54930),
#  ('sampai', 54890),
#  ('pulau', 54851),
#  ('lama', 54809),
#  ('her', 54781),
#  ('win', 54746),
#  ('tanpa', 54685),
#  ('mungkin', 54565),
#  ('pesona', 54149),
#  ('samsung', 54044),
#  ('that', 53957),
#  ('program', 53871),
#  ('chinese', 53718),
#  ('don', 53643),
#  ('syarikat', 53562),
#  ('maaf', 53418),
#  ('aliff', 53216),
#  ('wan', 53168),
#  ('lagu', 53113),
#  ('cetak', 53113),
#  ('ambil', 53072),
#  ('parti', 52972),
#  ('tentang', 52885),
#  ('rss', 52879),
#  ('an', 52787),
#  ('bank', 52754),
#  ('bawa', 52748),
#  ('adreena', 52732),
#  ('iylia', 52732),
#  ('siti', 52589),
#  ('menang', 52565),
#  ('makanan', 52536),
#  ('agentnet', 52448),
#  ('lee', 52446),
#  ('shah', 52317),
#  ('khaleeda', 52154),
#  ('demi', 52072),
#  ('buka', 52060),
#  ('money', 52047),
#  ('malam', 51960),
#  ('pura', 51855),
#  ('rashikin', 51793),
#  ('galaxy', 51785),
#  ('stailo', 51618),
#  ('horizon', 51580),
#  ('atas', 51575),
#  ('ketika', 51427),
#  ('cup', 51335),
#  ('varia', 51321),
#  ('set', 51219),
#  ('genk', 51219),
#  ('kumpulan', 51213),
#  ('last', 51203),
#  ('lima', 51092),
#  ('best', 50955),
#  ('bapa', 50949),
#  ('masuk', 50788),
#  ('car', 50717),
#  ('hadir', 50704),
#  ('police', 50701),
#  ('affairs', 50233),
#  ('ex', 50110),
#  ('nafi', 49815),
#  ('punca', 49787),
#  ('haji', 49679),
#  ('transfer', 49675),
#  ('reviews', 49642),
#  ('remaja', 49618),
#  ('mohon', 49590),
#  ('house', 49460),
#  ('kekal', 49454),
#  ('condo', 49393),
#  ('menu', 49379),
#  ('guides', 49275),
#  ('day', 49224),
#  ('kuiz', 49133),
#  ('bayi', 49077),
#  ('month', 49068),
#  ('options', 49043),
#  ('tinggi', 48989),
#  ('govt', 48939),
#  ('sprm', 48822),
#  ('kaw', 48789),
#  ('sekitar', 48763),
#  ('kim', 48680),
#  ('korea', 48619),
#  ('so', 48489),
#  ('sundaresan', 48413),
#  ('keeshaanan', 48413),
#  ('tvkosmo', 48350),
#  ('secara', 48346),
#  ('dedah', 48075),
#  ('buy', 48033),
#  ('banyak', 48022),
#  ('sri', 47934),
#  ('mh', 47914),
#  ('jawatan', 47868),
#  ('government', 47844),
#  ('perdana', 47767),
#  ('sebelum', 47695),
#  ('emas', 47689),
#  ('mampu', 47629),
#  ('terbuka', 47623),
#  ('re', 47520),
#  ('je', 47439),
#  ('siasat', 47427),
#  ('sempena', 47324),
#  ('tempatan', 47246),
#  ('usahawan', 47218),
#  ('menarik', 47068),
#  ('minit', 47061),
#  ('lancar', 47005),
#  ('hilang', 46868),
#  ('chong', 46865),
#  ('terhadap', 46833),
#  ('belum', 46805),
#  ('wilayah', 46438),
#  ('empat', 46370),
#  ('kit', 46228),
#  ('talks', 46168),
#  ('pusat', 46162),
#  ('kerja', 46112),
#  ('million', 46085),
#  ('masalah', 45985),
#  ('wei', 45883),
#  ('rosmah', 45750),
#  ('p', 45728),
#  ('guru', 45698),
#  ('semangat', 45671),
#  ('get', 45540),
#  ('salah', 45451),
#  ('athletics', 45327),
#  ('undang', 45325),
#  ('suka', 45309),
#  ('kerjasama', 45247),
#  ('incredible', 45244),
#  ('duit', 45168),
#  ('siang', 45118),
#  ('editor', 45082),
#  ('artis', 45056),
#  ('find', 44996),
#  ('perkara', 44905),
#  ('keluar', 44870),
#  ('cinta', 44821),
#  ('ketua', 44798),
#  ('syed', 44752),
#  ('english', 44734),
#  ('thailand', 44728),
#  ('kota', 44708),
#  ('dulu', 44646),
#  ('followers', 44593),
#  ('jalan', 44517),
#  ('fesyen', 44515),
#  ('masjid', 44494),
#  ('wajib', 44470),
#  ('pemimpin', 44271),
#  ('show', 44089),
#  ('nama', 44063),
#  ('sejarah', 44031),
#  ('omar', 43991),
#  ('ahead', 43921),
#  ('khairul', 43901),
#  ('neelofa', 43900),
#  ('launches', 43874),
#  ('questions', 43865),
#  ('mula', 43768),
#  ('lepas', 43763),
#  ('national', 43762),
#  ('tanah', 43751),
#  ('aku', 43728),
#  ('again', 43557),
#  ('because', 43550),
#  ('h', 43534),
#  ('when', 43533),
#  ('betul', 43483),
#  ('australia', 43438),
#  ('billion', 43283),
#  ('nahas', 43262),
#  ('telefon', 43178),
#  ('itu', 43098),
#  ('features', 43069),
#  ('open', 43034),
#  ('hadi', 42969),
#  ('tells', 42968),
#  ('wacana', 42911),
#  ('finance', 42806),
#  ('local', 42733),
#  ('tangan', 42638),
#  ('public', 42616),
#  ('mohd', 42507),
#  ('tok', 42479),
#  ('nizam', 42383),
#  ('programme', 42332),
#  ('peluang', 42302),
#  ('hide', 42300),
#  ('save', 42276),
#  ('bunuh', 42153),
#  ('projek', 42149),
#  ('com', 42147),
#  ('iklan', 42026),
#  ('singapura', 41995),
#  ('back', 41919),
#  ('hubungan', 41916),
#  ('see', 41894),
#  ('xiaomi', 41880),
#  ('know', 41830),
#  ('just', 41821),
#  ('skop', 41758),
#  ('mazlan', 41736),
#  ('apple', 41596),
#  ('only', 41585),
#  ('kelab', 41522),
#  ('fmt', 41492),
#  ('perancis', 41394),
#  ('surat', 41384),
#  ('subscribe', 41231),
#  ('do', 41216),
#  ('semi', 41206),
#  ('cari', 41006),
#  ('dapatkan', 40870),
#  ('profile', 40863),
#  ('high', 40775),
#  ('residential', 40772),
#  ('tindakan', 40764),
#  ('pakai', 40614),
#  ('rafiq', 40612),
#  ('korporat', 40560),
#  ('agent', 40499),
#  ('say', 40485),
#  ('food', 40442),
#  ('united', 40411),
#  ('masyarakat', 40402),
#  ('shock', 40289),
#  ('even', 40166),
#  ('pengiklanan', 40083),
#  ('f', 40069),
#  ('king', 40065),
#  ('nicol', 40060),
#  ('muzik', 40041),
#  ('market', 39936),
#  ('feedback', 39923),
#  ('sama', 39869),
#  ('tengok', 39866),
#  ('motogp', 39865),
#  ('kong', 39809),
#  ('insta', 39748),
#  ('agents', 39728),
#  ('disclaimer', 39728),
#  ('laporan', 39512),
#  ('malaysians', 39490),
#  ('condos', 39450),
#  ('real', 39395),
#  ('detached', 39346),
#  ('beritaharian', 39330),
#  ('produk', 39326),
#  ('help', 39277),
#  ('make', 39251),
#  ('red', 39221),
#  ('site', 38996),
#  ('tarik', 38964),
#  ('tu', 38909),
#  ('atlet', 38883),
#  ('pinang', 38830),
#  ('team', 38801),
#  ('polisi', 38624),
#  ('bajet', 38508),
#  ('free', 38482),
#  ('forum', 38475),
#  ('tweets', 38465),
#  ('promo', 38460),
#  ('kenyataan', 38373),
#  ('still', 38249),
#  ('berjaya', 38215),
#  ('macc', 38198),
#  ('ad', 38165),
#  ('cantik', 38146),
#  ('sokong', 38134),
#  ('rumours', 38130),
#  ('dortmund', 38122),
#  ('awal', 38082),
#  ('utara', 38013),
#  ('sitemap', 38012),
#  ('fa', 37954),
#  ('penduduk', 37912),
#  ('kerjaya', 37856),
#  ('giroud', 37811),
#  ('tawar', 37767),
#  ('resepi', 37632),
#  ('prime', 37595),
#  ('sokongan', 37559),
#  ('kaki', 37503),
#  ('rantau', 37480),
#  ('saman', 37404),
#  ('woman', 37397),
#  ('correa', 37332),
#  ('allah', 37296),
#  ('behind', 37293),
#  ('television', 37271),
#  ('mereka', 37257),
#  ('kurang', 37243),
#  ('keputusan', 37198),
#  ('aidilfitri', 37172),
#  ('askguru', 37022),
#  ('dakwa', 36976),
#  ('things', 36956),
#  ('seorang', 36954),
#  ('years', 36826),
#  ('pelakon', 36779),
#  ('pula', 36757),
#  ('peguam', 36714),
#  ('penafian', 36708),
#  ('baju', 36676),
#  ('permotoran', 36608),
#  ('pekerja', 36595),
#  ('social', 36592),
#  ('another', 36548),
#  ('energy', 36510),
#  ('city', 36500),
#  ('hong', 36498),
#  ('akhir', 36461),
#  ('jual', 36435),
#  ('hartanah', 36387),
#  ('people', 36069),
#  ('girl', 36056),
#  ('kedua', 36044),
#  ('smash', 35956),
#  ('bayar', 35913),
#  ('they', 35846),
#  ('dadah', 35812),
#  ('pengalaman', 35810),
#  ('janji', 35798),
#  ('khairy', 35720),
#  ('rafizi', 35715),
#  ('anti', 35705),
#  ('syafiq', 35660),
#  ('seagames', 35652),
#  ('movies', 35627),
#  ('setiap', 35586),
#  ('sosial', 35577),
#  ('sebenar', 35506),
#  ('singh', 35489),
#  ('kasih', 35475),
#  ('adib', 35462),
#  ('kamera', 35442),
#  ('palsu', 35368),
#  ('directory', 35302),
#  ('lensa', 35284),
#  ('player', 35278),
#  ('perkahwinan', 35258),
#  ('development', 35153),
#  ('bawah', 35153),
#  ('mingguan', 35107),
#  ('security', 35052),
#  ('mengaku', 34903),
#  ('b', 34868),
#  ('jakarta', 34856),
#  ('must', 34841),
#  ('turun', 34830),
#  ('pelancongan', 34763),
#  ('too', 34742),
#  ('letak', 34722),
#  ('bencana', 34705),
#  ('pilih', 34698),
#  ('memang', 34690),
#  ('tutup', 34683),
#  ('tahniah', 34665),
#  ('malays', 34653),
#  ('group', 34636),
#  ('jumpa', 34605),
#  ('great', 34579),
#  ('royal', 34549),
#  ('sara', 34543),
#  ('court', 34537),
#  ('gold', 34508),
#  ('klang', 34496),
#  ('undi', 34470),
#  ('anggota', 34469),
#  ('kuasa', 34461),
#  ('saddiq', 34452),
#  ('minggu', 34450),
#  ('mufti', 34405),
#  ('tempat', 34398),
#  ('balik', 34302),
#  ('me', 34289),
#  ('cricket', 34258),
#  ('baca', 34247),
#  ('ge', 34242),
#  ('race', 34109),
#  ('down', 34074),
#  ('special', 34061),
#  ('selected', 34051),
#  ('official', 33970),
#  ('she', 33969),
#  ('serangan', 33959),
#  ('kampus', 33917),
#  ('artikel', 33876),
#  ('take', 33865),
#  ('education', 33842),
#  ('aksi', 33804),
#  ('g', 33803),
#  ('wajah', 33742),
#  ('quran', 33675),
#  ('kemalangan', 33624),
#  ('mi', 33560),
#  ('good', 33452),
#  ('south', 33382),
#  ('peribadi', 33381),
#  ('hospital', 33366),
#  ('khabar', 33364),
#  ('halal', 33350),
#  ('him', 33349),
#  ('release', 33334),
#  ('problem', 33324),
#  ('search', 33323),
#  ('fakta', 33250),
#  ('bermula', 33210),
#  ('gagal', 33184),
#  ('pemandu', 33154),
#  ('terma', 33137),
#  ('pandang', 33116),
#  ('ain', 33016),
#  ('chief', 32978),
#  ('ibrahim', 32861),
#  ('respon', 32825),
#  ('syukri', 32792),
#  ('family', 32786),
#  ('end', 32674),
#  ('office', 32615),
#  ('peranti', 32549),
#  ('gst', 32526),
#  ('asli', 32524),
#  ('pergi', 32485),
#  ('click', 32430),
#  ('than', 32323),
#  ('haris', 32229),
#  ('malacca', 32210),
#  ('aura', 32141),
#  ('tetap', 32122),
#  ('kulit', 32070),
#  ('doing', 32058),
#  ('elak', 31983),
#  ('adam', 31969),
#  ('bombshell', 31934),
#  ('load', 31864),
#  ('ready', 31824),
#  ('permainan', 31673),
#  ('kampung', 31670),
#  ('akhirnya', 31649),
#  ('review', 31621),
#  ('subang', 31618),
#  ('hotel', 31555),
#  ('tech', 31529),
#  ('proton', 31502),
#  ('percuma', 31497),
#  ('bangga', 31491),
#  ('archived', 31489),
#  ('blog', 31474),
#  ('galeri', 31394),
#  ('resources', 31366),
#  ('awam', 31324),
#  ('international', 31275),
#  ('sedap', 31272),
#  ('pengguna', 31269),
#  ('sah', 31264),
#  ('letters', 31230),
#  ('dijangka', 31218),
#  ('barang', 31214),
#  ('sambutan', 31192),
#  ('sangat', 31182),
#  ('lokasi', 31162),
#  ('zakir', 31138),
#  ('week', 31116),
#  ('star', 31105),
#  ('tiba', 31095),
#  ('tragedi', 31041),
#  ('jawab', 30990),
#  ('ppbm', 30983),
#  ('adalah', 30976),
#  ('cedera', 30975),
#  ('basikal', 30949),
#  ('tingkat', 30940),
#  ('minyak', 30868),
#  ('hanafis', 30844),
#  ('own', 30842),
#  ('perempuan', 30791),
#  ('bilion', 30783),
#  ('grand', 30668),
#  ('want', 30607),
#  ('si', 30587),
#  ('pasti', 30563),
#  ('overseas', 30550),
#  ('setempat', 30529),
#  ('sumber', 30468),
#  ('pemuda', 30461),
#  ('pintar', 30458),
#  ('muslim', 30446),
#  ('ecrl', 30403),
#  ('akar', 30368),
#  ('swee', 30333),
#  ('razak', 30330),
#  ('selling', 30286),
#  ('upcoming', 30264),
#  ('east', 30242),
#  ('ulasan', 30198)]

# %%
rows = []
with open('MASTER.LINGUISTIC.2GRAM.big.csv', 'rt' ,encoding='utf8', newline='') as f:
    c = csv.reader(f)
    for i, row in enumerate(c):
        if (i + 1) % 1000000 == 0:
            print(i + 1)
        if row[0] == 'MALAY':
            rows.append(row)
# Out:
# 1000000
# 2000000
# 3000000
# 4000000
# 5000000
# 6000000
# 7000000
# 8000000
# 9000000
# 10000000
# 11000000
# 12000000
# 13000000
# 14000000
# 15000000
# 16000000
# 17000000
# 18000000
# 19000000
# 20000000
# 21000000
# 22000000
# 23000000
# 24000000
# 25000000
# 26000000
# 27000000
# 28000000
# 29000000
# 30000000
# 31000000
# 32000000
# 33000000
# 34000000
# 35000000
# 36000000
# 37000000
# 38000000
# 39000000
# 40000000
# 41000000
# 42000000
# 43000000
# 44000000
# 45000000
# 46000000
# 47000000
# 48000000
# 49000000
# 50000000
# 51000000
# 52000000
# 53000000
# 54000000
# 55000000
# 56000000
# 57000000
# 58000000
# 59000000
# 60000000
# 61000000
# 62000000
# 63000000
# 64000000
# 65000000
# 66000000
# 67000000
# 68000000
# 69000000
# 70000000
# 71000000
# 72000000
# 73000000
# 74000000
# 75000000
# 76000000
# 77000000
# 78000000
# 79000000
# 80000000
# 81000000
# 82000000
# 83000000
# 84000000
# 85000000
# 86000000
# 87000000
# 88000000
# 89000000
# 90000000
# 91000000
# 92000000
# 93000000
# 94000000
# 95000000
# 96000000
# 97000000
# 98000000
# 99000000
# 100000000
# 101000000
# 102000000
# 103000000
# 104000000
# 105000000
# 106000000
# 107000000
# 108000000
# 109000000
# 110000000
# 111000000
# 112000000
# 113000000
# 114000000
# 115000000
# 116000000
# 117000000
# 118000000
# 119000000
# 120000000
# 121000000
# 122000000
# 123000000
# 124000000
# 125000000
# 126000000
# 127000000
# 128000000
# 129000000
# 130000000
# 131000000
# 132000000
# 133000000
# 134000000
# 135000000
# 136000000
# 137000000
# 138000000
# 139000000
# 140000000
# 141000000
# 142000000
# 143000000
# 144000000
# 145000000
# 146000000
# 147000000
# 148000000
# 149000000
# 150000000
# 151000000
# 152000000
# 153000000
# 154000000
# 155000000
# 156000000
# 157000000
# 158000000
# 159000000
# 160000000
# 161000000
# 162000000
# 163000000
# 164000000
# 165000000
# 166000000
# 167000000
# 168000000
# 169000000
# 170000000
# 171000000
# 172000000
# 173000000
# 174000000
# 175000000
# 176000000
# 177000000
# 178000000
# 179000000
# 180000000
# 181000000
# 182000000
# 183000000
# 184000000
# 185000000
# 186000000
# 187000000
# 188000000
# 189000000
# 190000000
# 191000000
# 192000000
# 193000000
# 194000000
# 195000000
# 196000000
# 197000000
# 198000000
# 199000000
# 200000000
# 201000000
# 202000000
# 203000000
# 204000000
# 205000000
# 206000000
# 207000000
# 208000000
# 209000000
# 210000000
# 211000000
# 212000000
# 213000000
# 214000000
# 215000000
# 216000000
# 217000000
# 218000000
# 219000000
# 220000000
# 221000000
# 222000000
# 223000000
# 224000000
# 225000000
# 226000000
# 227000000
# 228000000
# 229000000
# 230000000
# 231000000
# 232000000
# 233000000
# 234000000
# 235000000
# 236000000
# 237000000
# 238000000
# 239000000
# 240000000
# 241000000
# 242000000
# 243000000
# 244000000
# 245000000
# 246000000
# 247000000
# 248000000
# 249000000
# 250000000
# 251000000
# 252000000
# 253000000
# 254000000
# 255000000
# 256000000
# 257000000
# 258000000
# 259000000
# 260000000
# 261000000
# 262000000
# 263000000
# 264000000
# 265000000
# 266000000
# 267000000
# 268000000
# 269000000
# 270000000
# 271000000
# 272000000
# 273000000
# 274000000
# 275000000
# 276000000
# 277000000
# 278000000
# 279000000
# 280000000
# 281000000
# 282000000
# 283000000
# 284000000
# 285000000
# 286000000
# 287000000
# 288000000
# 289000000
# 290000000
# 291000000
# 292000000
# 293000000
# 294000000
# 295000000
# 296000000
# 297000000
# 298000000
# 299000000
# 300000000
# 301000000
# 302000000
# 303000000
# 304000000
# 305000000
# 306000000
# 307000000
# 308000000
# 309000000
# 310000000
# 311000000
# 312000000
# 313000000
# 314000000
# 315000000
# 316000000
# 317000000
# 318000000
# 319000000
# 320000000
# 321000000
# 322000000
# 323000000
# 324000000
# 325000000
# 326000000
# 327000000
# 328000000
# 329000000
# 330000000
# 331000000
# 332000000
# 333000000
# 334000000
# 335000000
# 336000000
# 337000000
# 338000000
# 339000000
# 340000000
# 341000000
# 342000000
# 343000000
# 344000000
# 345000000
# 346000000
# 347000000
# 348000000
# 349000000
# 350000000
# 351000000
# 352000000
# 353000000
# 354000000
# 355000000
# 356000000
# 357000000
# 358000000
# 359000000
# 360000000
# 361000000
# 362000000
# 363000000
# 364000000
# 365000000
# 366000000
# 367000000
# 368000000
# 369000000
# 370000000
# 371000000
# 372000000
# 373000000
# 374000000
# 375000000
# 376000000
# 377000000
# 378000000
# 379000000
# 380000000
# 381000000
# 382000000
# 383000000
# 384000000
# 385000000
# 386000000
# 387000000
# 388000000
# 389000000
# 390000000
# 391000000
# 392000000
# 393000000
# 394000000
# 395000000
# 396000000
# 397000000
# 398000000
# 399000000
# 400000000
# 401000000
# 402000000
# 403000000
# 404000000
# 405000000
# 406000000
# 407000000
# 408000000
# 409000000
# 410000000
# 411000000
# 412000000
# 413000000
# 414000000
# 415000000
# 416000000
# 417000000
# 418000000
# 419000000
# 420000000
# 421000000
# 422000000
# 423000000
# 424000000
# 425000000
# 426000000
# 427000000
# 428000000
# 429000000
# 430000000
# 431000000
# 432000000
# 433000000
# 434000000
# 435000000
# 436000000
# 437000000
# 438000000
# 439000000
# 440000000
# 441000000
# 442000000
# 443000000
# 444000000
# 445000000
# 446000000
# 447000000
# 448000000
# 449000000
# 450000000
# 451000000
# 452000000
# 453000000
# 454000000
# 455000000
# 456000000
# 457000000
# 458000000
# 459000000
# 460000000
# 461000000
# 462000000
# 463000000
# 464000000
# 465000000
# 466000000
# 467000000
# 468000000
# 469000000
# 470000000
# 471000000
# 472000000
# 473000000
# 474000000
# 475000000
# 476000000
# 477000000
# 478000000
# 479000000
# 480000000
# 481000000
# 482000000
# 483000000
# 484000000
# 485000000
# 486000000
# 487000000
# 488000000
# 489000000
# 490000000
# 491000000
# 492000000
# 493000000
# 494000000
# 495000000
# 496000000
# 497000000
# 498000000
# 499000000
# 500000000
# 501000000
# 502000000
# 503000000
# 504000000
# 505000000
# 506000000
# 507000000
# 508000000
# 509000000
# 510000000
# 511000000
# 512000000
# 513000000
# 514000000
# 515000000
# 516000000
# 517000000
# 518000000
# 519000000
# 520000000
# 521000000
# 522000000
# 523000000
# 524000000
# 525000000
# 526000000
# 527000000
# 528000000
# 529000000
# 530000000
# 531000000
# 532000000
# 533000000
# 534000000
# 535000000
# 536000000
# 537000000
# 538000000
# 539000000
# 540000000
# 541000000
# 542000000
# 543000000
# 544000000
# 545000000
# 546000000
# 547000000
# 548000000
# 549000000
# 550000000
# 551000000
# 552000000
# 553000000
# 554000000
# 555000000
# 556000000
# 557000000
# 558000000
# 559000000
# 560000000
# 561000000
# 562000000
# 563000000
# 564000000
# 565000000
# 566000000
# 567000000
# 568000000
# 569000000
# 570000000
# 571000000
# 572000000
# 573000000
# 574000000
# 575000000
# 576000000
# 577000000
# 578000000
# 579000000
# 580000000
# 581000000
# 582000000
# 583000000
# 584000000
# 585000000
# 586000000
# 587000000
# 588000000
# 589000000
# 590000000
# 591000000
# 592000000
# 593000000
# 594000000
# 595000000
# 596000000
# 597000000
# 598000000
# 599000000
# 600000000
# 601000000
# 602000000
# 603000000
# 604000000
# 605000000
# 606000000
# 607000000
# 608000000
# 609000000
# 610000000
# 611000000
# 612000000
# 613000000
# 614000000
# 615000000
# 616000000
# 617000000
# 618000000
# 619000000
# 620000000
# 621000000
# 622000000
# 623000000
# 624000000
# 625000000
# 626000000
# 627000000
# 628000000
# 629000000
# 630000000
# 631000000
# 632000000
# 633000000
# 634000000
# 635000000
# 636000000
# 637000000
# 638000000
# 639000000
# 640000000
# 641000000
# 642000000
# 643000000
# 644000000
# 645000000
# 646000000
# 647000000
# 648000000
# 649000000
# 650000000
# 651000000
# 652000000
# 653000000
# 654000000
# 655000000
# 656000000
# 657000000
# 658000000
# 659000000
# 660000000
# 661000000
# 662000000
# 663000000
# 664000000
# 665000000
# 666000000
# 667000000
# 668000000
# 669000000
# 670000000
# 671000000
# 672000000
# 673000000
# 674000000
# 675000000
# 676000000
# 677000000
# 678000000
# 679000000
# 680000000
# 681000000
# 682000000
# 683000000
# 684000000
# 685000000
# 686000000
# 687000000

# %%
def twogram(words):
    tmp = None
    for word in words:
        if tmp is not None:
            yield f'{tmp} {word}'
        tmp = word

# %%
word_2_grams = Counter()
for row in rows:
    for word in twogram(words(row[1])):
        word_2_grams[word.casefold()] += int(row[2])

# %%
len(word_2_grams)
# Out:
# 1075490

# %%
word_2_grams.most_common(100)
# Out:
# [('properties for', 498190),
#  ('for rent', 340869),
#  ('for sale', 329056),
#  ('read more', 223679),
#  ('sale in', 197081),
#  ('rent in', 196651),
#  ('new properties', 183540),
#  ('yang lalu', 183199),
#  ('mark leo', 176144),
#  ('properties in', 157588),
#  ('jam yang', 148698),
#  ('ministry of', 147831),
#  ('mt webmaster', 143138),
#  ('bootstrap slideshow', 116312),
#  ('to be', 106372),
#  ('no max', 104912),
#  ('no min', 104912),
#  ('raja petra', 97350),
#  ('kuala lumpur', 96221),
#  ('privacy policy', 96108),
#  ('petra kamarudin', 93679),
#  ('sea games', 91063),
#  ('guan eng', 87677),
#  ('dr m', 87426),
#  ('of the', 83337),
#  ('negeri sembilan', 80239),
#  ('s pura', 76009),
#  ('news list', 75102),
#  ('rtb station', 74262),
#  ('gaya hidup', 73822),
#  ('nigel dusanjh', 71391),
#  ('about us', 70444),
#  ('tahun harakah', 67300),
#  ('meninggal dunia', 65657),
#  ('hubungi kami', 64722),
#  ('gowri krishnan', 64402),
#  ('rd minion', 63949),
#  ('log in', 63407),
#  ('contact us', 62569),
#  ('di sini', 62506),
#  ('azwa rahman', 61564),
#  ('terms of', 60813),
#  ('rencana utama', 59516),
#  ('luar negara', 58897),
#  ('no holds', 58791),
#  ('holds barred', 58791),
#  ('tun m', 57781),
#  ('of power', 57669),
#  ('di malaysia', 57366),
#  ('anda di', 57227),
#  ('tinggalkan komen', 56839),
#  ('komen anda', 56709),
#  ('tolak tawaran', 56669),
#  ('corridors of', 55710),
#  ('guide to', 55502),
#  ('jho low', 55146),
#  ('dr mahathir', 54717),
#  ('rm juta', 54533),
#  ('commercial properties', 53226),
#  ('houses for', 52829),
#  ('iylia adreena', 52732),
#  ('khaleeda rashikin', 51793),
#  ('edisi cetak', 51659),
#  ('in malaysia', 51161),
#  ('view more', 49966),
#  ('new project', 49452),
#  ('pakatan harapan', 49312),
#  ('keeshaanan sundaresan', 48413),
#  ('in penang', 48232),
#  ('bola sepak', 47997),
#  ('minister s', 47643),
#  ('in the', 45428),
#  ('piala dunia', 45350),
#  ('shah alam', 44023),
#  ('kit siang', 43587),
#  ('in johor', 43110),
#  ('world cup', 42219),
#  ('in kuala', 41597),
#  ('khairul nizam', 40945),
#  ('to buying', 40200),
#  ('residential land', 40120),
#  ('rafiq mazlan', 39535),
#  ('chong wei', 39529),
#  ('lihat selebihnya', 39152),
#  ('komuniti kita', 38439),
#  ('follow propertyguru', 38250),
#  ('propertyguru on', 38250),
#  ('nicol david', 37573),
#  ('to liverpool', 37391),
#  ('transfer rumours', 37389),
#  ('to dortmund', 37344),
#  ('top transfer', 37343),
#  ('correa to', 37329),
#  ('giroud to', 37329),
#  ('of use', 37073),
#  ('mengenai kami', 36670),
#  ('hide options', 36154),
#  ('talks about', 36109),
#  ('incredible badminton', 35701),
#  ('most incredible', 35701)]

# %%
[(w,c) for w, c in word_2_grams.most_common() if w.startswith('air ')]
# Out:
# [('air mata', 8673),
#  ('air sejuk', 3835),
#  ('air asia', 3768),
#  ('air liur', 2447),
#  ('air di', 2268),
#  ('air terjun', 1600),
#  ('air sukarkan', 1560),
#  ('air selangor', 1551),
#  ('air bawah', 1421),
#  ('air dalam', 1368),
#  ('air tangan', 1354),
#  ('air kencing', 1316),
#  ('air panas', 1182),
#  ('air bersih', 1166),
#  ('air hostess', 1060),
#  ('air luah', 1040),
#  ('air dengan', 828),
#  ('air vent', 776),
#  ('air by', 754),
#  ('air again', 733),
#  ('air jt', 727),
#  ('air yang', 725),
#  ('air terhempas', 704),
#  ('air on', 703),
#  ('air ketum', 702),
#  ('air percuma', 678),
#  ('air paling', 665),
#  ('air bunga', 607),
#  ('air zam', 580),
#  ('air to', 520),
#  ('air minuman', 509),
#  ('air sungai', 458),
#  ('air quality', 455),
#  ('air milo', 446),
#  ('air pollution', 437),
#  ('air about', 417),
#  ('air kecil', 412),
#  ('air dan', 404),
#  ('air travel', 382),
#  ('air teh', 379),
#  ('air keruh', 379),
#  ('air menurut', 374),
#  ('air passengers', 353),
#  ('air putih', 351),
#  ('air pulih', 348),
#  ('air kosong', 336),
#  ('air abu', 330),
#  ('air force', 327),
#  ('air dijangka', 326),
#  ('air manis', 323),
#  ('air ketuban', 320),
#  ('air tak', 317),
#  ('air sendiri', 305),
#  ('air lama', 296),
#  ('air besar', 294),
#  ('air ditemui', 283),
#  ('air laut', 279),
#  ('air hujan', 273),
#  ('air tenaga', 273),
#  ('air mineral', 260),
#  ('air lembah', 257),
#  ('air untuk', 255),
#  ('air kelapa', 251),
#  ('air dipecat', 250),
#  ('air of', 250),
#  ('air kuasa', 240),
#  ('air pasang', 239),
#  ('air dikunjungi', 236),
#  ('air secara', 233),
#  ('air sebelum', 229),
#  ('air terawat', 229),
#  ('air balloon', 219),
#  ('air semarakkan', 214),
#  ('air katira', 213),
#  ('air selamat', 211),
#  ('air kumbahan', 208),
#  ('air buangan', 207),
#  ('air kotak', 204),
#  ('air jejas', 204),
#  ('air membengkak', 202),
#  ('air buat', 200),
#  ('air sungguh', 198),
#  ('air kerana', 197),
#  ('air tiada', 187),
#  ('air zamzam', 186),
#  ('air crash', 180),
#  ('air kopi', 178),
#  ('air kemboja', 176),
#  ('air masak', 175),
#  ('air selesai', 174),
#  ('air produk', 170),
#  ('air jadi', 167),
#  ('air bermula', 166),
#  ('air lumpur', 165),
#  ('air rosak', 162),
#  ('air gatal', 161),
#  ('air kongsi', 151),
#  ('air tepi', 150),
#  ('air tercemar', 150),
#  ('air eateries', 148),
#  ('air tawar', 145),
#  ('air sedunia', 144),
#  ('air meriah', 144),
#  ('air mani', 143),
#  ('air strikes', 141),
#  ('air marine', 138),
#  ('air the', 135),
#  ('air itam', 133),
#  ('air wujud', 132),
#  ('air muka', 131),
#  ('air je', 127),
#  ('air terputus', 122),
#  ('air stewardesses', 120),
#  ('air tuaspring', 119),
#  ('air kencingnya', 119),
#  ('air jet', 117),
#  ('air tapis', 116),
#  ('air perlu', 115),
#  ('air berkecai', 115),
#  ('air sampai', 114),
#  ('air mobility', 113),
#  ('air dedah', 113),
#  ('air rebusan', 112),
#  ('air negara', 112),
#  ('air gula', 110),
#  ('air sebagai', 110),
#  ('air dilanjutkan', 110),
#  ('air berpindah', 109),
#  ('air kita', 108),
#  ('air lower', 108),
#  ('air baru', 107),
#  ('air is', 107),
#  ('air strike', 107),
#  ('air bag', 106),
#  ('air france', 106),
#  ('air naik', 105),
#  ('air rai', 104),
#  ('air mampu', 103),
#  ('air boleh', 103),
#  ('air saman', 102),
#  ('air mentah', 102),
#  ('air esok', 101),
#  ('air dipercayai', 101),
#  ('air dilancarkan', 100),
#  ('air paip', 100),
#  ('air gedang', 99),
#  ('air india', 99),
#  ('air sisa', 97),
#  ('air in', 96),
#  ('air terpanjang', 95),
#  ('air tiga', 93),
#  ('air hantar', 93),
#  ('air hotel', 92),
#  ('air tembak', 92),
#  ('air dari', 90),
#  ('air citarum', 90),
#  ('air semasa', 89),
#  ('air halau', 89),
#  ('air bateri', 88),
#  ('air oh', 86),
#  ('air as', 85),
#  ('air tidak', 84),
#  ('air bakal', 84),
#  ('air batu', 83),
#  ('air lancar', 83),
#  ('air baharu', 83),
#  ('air nabeez', 82),
#  ('air sejak', 80),
#  ('air kepada', 80),
#  ('air botol', 79),
#  ('air rendah', 75),
#  ('air plane', 74),
#  ('air kelantan', 72),
#  ('air china', 71),
#  ('air maut', 70),
#  ('air ditemukan', 70),
#  ('air kampung', 69),
#  ('air supply', 69),
#  ('air masih', 69),
#  ('air muda', 68),
#  ('air usaha', 67),
#  ('air menghijau', 67),
#  ('air choa', 67),
#  ('air tuas', 67),
#  ('air biasanya', 67),
#  ('air ketika', 65),
#  ('air penawar', 64),
#  ('air disiasat', 63),
#  ('air hsbe', 63),
#  ('air wreckage', 62),
#  ('air kini', 62),
#  ('air ip', 62),
#  ('air bijak', 62),
#  ('air johor', 60),
#  ('air s', 60),
#  ('air sambung', 60),
#  ('air sempat', 60),
#  ('air punca', 59),
#  ('air akan', 59),
#  ('air dihasilkan', 59),
#  ('air empangan', 59),
#  ('air flight', 59),
#  ('air restaurants', 59),
#  ('air rumah', 58),
#  ('air ganda', 58),
#  ('air dapat', 58),
#  ('air dinaikkan', 58),
#  ('air najis', 57),
#  ('air traffic', 57),
#  ('air for', 56),
#  ('air melimpah', 56),
#  ('air pada', 56),
#  ('air kritikal', 56),
#  ('air terjejas', 56),
#  ('air surut', 56),
#  ('air rendaman', 55),
#  ('air dicaj', 55),
#  ('air conditioner', 54),
#  ('air terkenal', 53),
#  ('air show', 53),
#  ('air ke', 53),
#  ('air lagi', 52),
#  ('air mencukupi', 52),
#  ('air lebih', 52),
#  ('air berpanjangan', 51),
#  ('air restoran', 51),
#  ('air moden', 51),
#  ('air berpusar', 51),
#  ('air secetek', 51),
#  ('air runtuh', 50),
#  ('air melanda', 50),
#  ('air stuns', 50),
#  ('air bertakung', 49),
#  ('air p', 49),
#  ('air terpelihara', 49),
#  ('air pula', 49),
#  ('air bedok', 48),
#  ('air berkarbonat', 48),
#  ('air kering', 48),
#  ('air mewah', 47),
#  ('air tengeh', 47),
#  ('air dipertingkat', 46),
#  ('air google', 46),
#  ('air a', 46),
#  ('air bagi', 46),
#  ('air terburuk', 46),
#  ('air hitam', 45),
#  ('air wakili', 45),
#  ('air daughter', 45),
#  ('air diteruskan', 44),
#  ('air bantu', 44),
#  ('air launches', 44),
#  ('air ajaib', 44),
#  ('air diambil', 43),
#  ('air agenda', 43),
#  ('air interview', 43),
#  ('air jika', 43),
#  ('air ditahan', 43),
#  ('air cuma', 43),
#  ('air riuh', 43),
#  ('air musnah', 42),
#  ('air wanita', 42),
#  ('air musim', 42),
#  ('air over', 42),
#  ('air affirms', 41),
#  ('air canada', 40),
#  ('air dibekal', 39),
#  ('air travellers', 39),
#  ('air terus', 39),
#  ('air sydney', 38),
#  ('air dibangkitkan', 38),
#  ('air ditutup', 38),
#  ('air pun', 38),
#  ('air lemon', 38),
#  ('air gun', 37),
#  ('air luar', 37),
#  ('air deal', 37),
#  ('air sma', 36),
#  ('air rm', 36),
#  ('air peranti', 36),
#  ('air termenung', 36),
#  ('air utama', 36),
#  ('air melebihi', 36),
#  ('air dikenal', 36),
#  ('air malaysia', 35),
#  ('air sabah', 35),
#  ('air jangka', 35),
#  ('air berterusan', 35),
#  ('air makin', 34),
#  ('air surveillance', 34),
#  ('air berkeladak', 34),
#  ('air deras', 34),
#  ('air jagung', 34),
#  ('air limau', 33),
#  ('air ugut', 33),
#  ('air terbang', 33),
#  ('air kedah', 33),
#  ('air zughar', 33),
#  ('air bermasalah', 32),
#  ('air dua', 32),
#  ('air berjaya', 32),
#  ('air drop', 32),
#  ('air rifles', 31),
#  ('air dahulu', 31),
#  ('air ini', 31),
#  ('air berjadual', 31),
#  ('air with', 31),
#  ('air tumpu', 31),
#  ('air terlalu', 31),
#  ('air harus', 30),
#  ('air disyaki', 30),
#  ('air due', 30),
#  ('air masuk', 30),
#  ('air splash', 30),
#  ('air tingkat', 30),
#  ('air introduces', 30),
#  ('air max', 30),
#  ('air mayat', 30),
#  ('air pahang', 29),
#  ('air belum', 29),
#  ('air sehari', 29),
#  ('air mask', 29),
#  ('air terpakai', 29),
#  ('air malam', 29),
#  ('air pulau', 28),
#  ('air adalah', 28),
#  ('air masagos', 28),
#  ('air radiator', 28),
#  ('air transport', 28),
#  ('air aircraft', 28),
#  ('air pecah', 27),
#  ('air confident', 26),
#  ('air dirawat', 26),
#  ('air diberi', 26),
#  ('air perak', 26),
#  ('air basuhan', 25),
#  ('air raids', 25),
#  ('air connectivity', 25),
#  ('air and', 25),
#  ('air purifier', 25),
#  ('air kurang', 24),
#  ('air mataku', 24),
#  ('air lalok', 24),
#  ('air toksik', 24),
#  ('air pembetung', 24),
#  ('air bisa', 24),
#  ('air dijual', 23),
#  ('air sudah', 23),
#  ('air terengganu', 23),
#  ('air lanas', 23),
#  ('air berpunca', 22),
#  ('air hampir', 22),
#  ('air akibat', 22),
#  ('air didapati', 22),
#  ('air sebahagian', 22),
#  ('air tickets', 21),
#  ('air bingung', 21),
#  ('air fares', 21),
#  ('air speed', 21),
#  ('air after', 21),
#  ('air pos', 21),
#  ('air mula', 21),
#  ('air tinggi', 21),
#  ('air terkorban', 20),
#  ('air defences', 20),
#  ('air padam', 20),
#  ('air sempena', 20),
#  ('air terhadap', 20),
#  ('air busan', 20),
#  ('air ends', 19),
#  ('air kekal', 19),
#  ('air new', 19),
#  ('air pdm', 19),
#  ('air bukit', 19),
#  ('air berjumlah', 18),
#  ('air merah', 18),
#  ('air mawar', 18),
#  ('air hadapi', 18),
#  ('air gesa', 18),
#  ('air kl', 18),
#  ('air direbus', 18),
#  ('air sekitar', 18),
#  ('air kecoh', 18),
#  ('air empat', 18),
#  ('air mendidih', 17),
#  ('air leak', 17),
#  ('air hujung', 17),
#  ('air cemaskan', 17),
#  ('air pancut', 17),
#  ('air longkang', 17),
#  ('air chepam', 17),
#  ('air cukup', 17),
#  ('air wilayah', 17),
#  ('air ceo', 17),
#  ('air at', 17),
#  ('air lima', 17),
#  ('air crashes', 17),
#  ('air turut', 16),
#  ('air gantung', 16),
#  ('air niugini', 16),
#  ('air boeing', 16),
#  ('air tasik', 16),
#  ('air black', 16),
#  ('air sumbang', 16),
#  ('air ganti', 16),
#  ('air keluar', 16),
#  ('air masin', 15),
#  ('air adil', 15),
#  ('air ogos', 15),
#  ('air tambahan', 15),
#  ('air hanya', 15),
#  ('air differences', 15),
#  ('air appoints', 14),
#  ('air diserah', 14),
#  ('air tersebar', 14),
#  ('air terbakar', 14),
#  ('air talks', 14),
#  ('air keutamaan', 14),
#  ('air dibuat', 14),
#  ('air semula', 14),
#  ('air awam', 13),
#  ('air terganggu', 13),
#  ('air selepas', 13),
#  ('air melaka', 13),
#  ('air grouses', 13),
#  ('air jual', 13),
#  ('air mudah', 13),
#  ('air sunday', 12),
#  ('air semakin', 12),
#  ('air tight', 12),
#  ('air arabia', 12),
#  ('air diperluas', 12),
#  ('air pengilang', 12),
#  ('air ikut', 12),
#  ('air world', 12),
#  ('air terawar', 12),
#  ('air hari', 12),
#  ('air kotor', 11),
#  ('air bomba', 11),
#  ('air hit', 11),
#  ('air base', 11),
#  ('air mohon', 11),
#  ('air contamination', 10),
#  ('air akar', 10),
#  ('air kudat', 10),
#  ('air suspends', 10),
#  ('air gara', 10),
#  ('air graviti', 10),
#  ('air kesan', 10),
#  ('air dibina', 10),
#  ('air exposes', 10),
#  ('air simpang', 10),
#  ('air keluli', 10),
#  ('air kuala', 10),
#  ('air kegunaan', 10),
#  ('air alami', 9),
#  ('air tandas', 9),
#  ('air setiu', 9),
#  ('air per', 9),
#  ('air sementara', 9),
#  ('air diserbu', 9),
#  ('air berlarutan', 9),
#  ('air dimeterai', 9),
#  ('air beri', 9),
#  ('air tebu', 9),
#  ('air takes', 9),
#  ('air berperingkat', 9),
#  ('air dirakam', 9),
#  ('air dah', 8),
#  ('air negeri', 8),
#  ('air operations', 8),
#  ('air diguna', 8),
#  ('air kuantan', 8),
#  ('air perkenal', 8),
#  ('air sukma', 8),
#  ('air cargo', 8),
#  ('air keliru', 8),
#  ('air seafood', 8),
#  ('air cuka', 8),
#  ('air adakan', 8),
#  ('air bebankan', 8),
#  ('air berlesen', 8),
#  ('air lopak', 8),
#  ('air dinasihat', 8),
#  ('air hulu', 8),
#  ('air banjir', 8),
#  ('air meninggal', 8),
#  ('air defenses', 8),
#  ('air safety', 8),
#  ('air defence', 7),
#  ('air lain', 7),
#  ('air seluruh', 7),
#  ('air brush', 7),
#  ('air previous', 7),
#  ('air telaga', 7),
#  ('air tuntut', 7),
#  ('air berisiko', 7),
#  ('air director', 7),
#  ('air rifle', 7),
#  ('air kacang', 7),
#  ('air langat', 7),
#  ('air indonesia', 7),
#  ('air balakong', 7),
#  ('air asam', 7),
#  ('air sah', 7),
#  ('air tenang', 6),
#  ('air busuk', 6),
#  ('air services', 6),
#  ('air capai', 6),
#  ('air lg', 6),
#  ('air diancam', 6),
#  ('air missile', 6),
#  ('air tentu', 6),
#  ('air bases', 6),
#  ('air sehingga', 6),
#  ('air diberkas', 6),
#  ('air didik', 6),
#  ('air diluluskan', 6),
#  ('air ranap', 6),
#  ('air bers', 5),
#  ('air penduduk', 5),
#  ('air kerap', 5),
#  ('air flooded', 5),
#  ('air kecemasan', 5),
#  ('air resumes', 5),
#  ('air tragedy', 5),
#  ('air patriarch', 5),
#  ('air khayal', 5),
#  ('air perlis', 5),
#  ('air larut', 5),
#  ('air special', 5),
#  ('air chief', 5),
#  ('air rage', 5),
#  ('air attacks', 5),
#  ('air tarikan', 5),
#  ('air bmlr', 5),
#  ('air warna', 5),
#  ('air conditioners', 5),
#  ('air digantung', 5),
#  ('air mulls', 5),
#  ('air dasar', 5),
#  ('air wajar', 5),
#  ('air golongan', 5),
#  ('air minum', 4),
#  ('air patrol', 4),
#  ('air berteknologi', 4),
#  ('air kembali', 4),
#  ('air tampung', 4),
#  ('air pertengahan', 4),
#  ('air jer', 4),
#  ('air babi', 4),
#  ('air passenger', 4),
#  ('air graffiti', 4),
#  ('air jordan', 4),
#  ('air minggu', 4),
#  ('air problem', 4),
#  ('air tahun', 4),
#  ('air demi', 4),
#  ('air takungan', 4),
#  ('air parit', 4),
#  ('air tanpa', 4),
#  ('air nafi', 4),
#  ('air handling', 4),
#  ('air munasabah', 4),
#  ('air setiap', 4),
#  ('air serta', 4),
#  ('air berulang', 4),
#  ('air conditioning', 4),
#  ('air ekoran', 4),
#  ('air libat', 4),
#  ('air perigi', 3),
#  ('air guna', 3),
#  ('air uzur', 3),
#  ('air lokasi', 3),
#  ('air elak', 3),
#  ('air collision', 3),
#  ('air all', 3),
#  ('air pilots', 3),
#  ('air dakwa', 3),
#  ('air moleh', 3),
#  ('air orang', 3),
#  ('air dipotong', 3),
#  ('air puts', 3),
#  ('air diperiksa', 3),
#  ('air back', 3),
#  ('air hq', 3),
#  ('air heiress', 3),
#  ('air berbau', 3),
#  ('air protest', 3),
#  ('air menggelegak', 3),
#  ('air sedia', 3),
#  ('air isnin', 3),
#  ('air travelers', 3),
#  ('air dota', 3),
#  ('air pistols', 3),
#  ('air bags', 3),
#  ('air tamatkan', 3),
#  ('air sandakan', 3),
#  ('air mulakan', 3),
#  ('air ada', 3),
#  ('air susulan', 2),
#  ('air lra', 2),
#  ('air mengamuk', 2),
#  ('air next', 2),
#  ('air dihentikan', 2),
#  ('air muktamad', 2),
#  ('air dulu', 2),
#  ('air sensor', 2),
#  ('air group', 2),
#  ('air mencapai', 2),
#  ('air may', 2),
#  ('air layan', 2),
#  ('air alternatif', 2),
#  ('air dunia', 2),
#  ('air bertahan', 2),
#  ('air bukan', 2),
#  ('air gandum', 2),
#  ('air walaupun', 2),
#  ('air hingga', 2),
#  ('air terbabas', 2),
#  ('air network', 2),
#  ('air merbok', 2),
#  ('air singapura', 2),
#  ('air deru', 2),
#  ('air canggih', 2),
#  ('air raid', 2),
#  ('air muara', 2),
#  ('air attack', 2),
#  ('air nira', 2),
#  ('air skim', 2),
#  ('air semua', 2),
#  ('air mencurah', 2),
#  ('air mulai', 2),
#  ('air disaster', 2),
#  ('air taja', 2),
#  ('air jordans', 2),
#  ('air lines', 2),
#  ('air saiz', 2),
#  ('air berbanding', 2),
#  ('air maritime', 2),
#  ('air crashjakarta', 2),
#  ('air must', 2),
#  ('air offers', 2),
#  ('air hospital', 2),
#  ('air lab', 2),
#  ('air meningkat', 1),
#  ('air labuan', 1),
#  ('air sumbangan', 1),
#  ('air tangguh', 1),
#  ('air filipina', 1),
#  ('air selar', 1),
#  ('air balloons', 1),
#  ('air sampah', 1),
#  ('air monitoring', 1),
#  ('air tuak', 1),
#  ('air lambat', 1),
#  ('air rancakkan', 1),
#  ('air taman', 1),
#  ('air flies', 1),
#  ('air setahun', 1),
#  ('air dibekalkan', 1),
#  ('air customers', 1),
#  ('air berhemah', 1),
#  ('air kocok', 1),
#  ('air bertutup', 1),
#  ('air direman', 1),
#  ('air kedua', 1),
#  ('air bersasar', 1),
#  ('air tin', 1),
#  ('air kolam', 1),
#  ('air sains', 1),
#  ('air buka', 1),
#  ('air pistol', 1),
#  ('air tie', 1),
#  ('air perancis', 1),
#  ('air putus', 1),
#  ('air landa', 1),
#  ('air menyukarkan', 1),
#  ('air zimbabwe', 1),
#  ('air kena', 1),
#  ('air tangki', 1),
#  ('air slabi', 1),
#  ('air osmosis', 1),
#  ('air spanish', 1),
#  ('air suam', 1),
#  ('air tanggungjawab', 1),
#  ('air sepanjang', 1),
#  ('air maroc', 1),
#  ('air berubah', 1),
#  ('air daun', 1),
#  ('air pact', 1),
#  ('air berlebihan', 1),
#  ('air balang', 1),
#  ('air cucian', 1),
#  ('air tebang', 1),
#  ('air museum', 1),
#  ('air maintains', 1),
#  ('air marina', 1),
#  ('air supaya', 1),
#  ('air four', 1),
#  ('air apm', 1),
#  ('air dilaksana', 1),
#  ('air lancarkan', 1),
#  ('air seperti', 1),
#  ('air terbongkar', 1),
#  ('air babitkan', 1),
#  ('air sesuka', 1),
#  ('air dijamin', 1),
#  ('air ranhill', 1),
#  ('air dingin', 1),
#  ('air terima', 1),
#  ('air semerak', 1),
#  ('air shuts', 1),
#  ('air regulation', 1),
#  ('air accidents', 1),
#  ('air mahu', 1),
#  ('air syawal', 1),
#  ('air transportation', 1)]

# %%
word_1_grams = Counter()
for words, count in word_2_grams.most_common():
    for word in words.split():
        word_1_grams[word] += count

# %%
len(word_1_grams)
# Out:
# 77707

# %%
word_1_grams.most_common(100)
# Out:
# [('to', 3020198),
#  ('in', 2712982),
#  ('for', 2559722),
#  ('di', 2276706),
#  ('of', 2074228),
#  ('the', 1843135),
#  ('s', 1300218),
#  ('yang', 1273597),
#  ('properties', 1215215),
#  ('malaysia', 1026458),
#  ('dengan', 970989),
#  ('untuk', 888952),
#  ('dan', 886084),
#  ('on', 860463),
#  ('a', 827675),
#  ('and', 802888),
#  ('ini', 783483),
#  ('ke', 757577),
#  ('dalam', 738041),
#  ('tak', 706016),
#  ('new', 658240),
#  ('rm', 658126),
#  ('tidak', 643949),
#  ('is', 627542),
#  ('more', 606008),
#  ('rent', 593839),
#  ('with', 552149),
#  ('sale', 545045),
#  ('jadi', 512983),
#  ('anak', 509116),
#  ('buat', 498053),
#  ('at', 464527),
#  ('no', 444388),
#  ('be', 431315),
#  ('akan', 430866),
#  ('najib', 423704),
#  ('as', 412970),
#  ('mahathir', 398924),
#  ('pada', 390717),
#  ('umno', 390672),
#  ('m', 379212),
#  ('boleh', 365123),
#  ('not', 345206),
#  ('saya', 345137),
#  ('hari', 343108),
#  ('perlu', 342857),
#  ('pas', 332684),
#  ('you', 332485),
#  ('tahun', 332213),
#  ('nak', 331671),
#  ('dr', 326718),
#  ('dari', 326464),
#  ('anda', 325273),
#  ('kepada', 317330),
#  ('korang', 315428),
#  ('will', 312533),
#  ('lebih', 309124),
#  ('ada', 304873),
#  ('by', 302071),
#  ('dunia', 301223),
#  ('negara', 299454),
#  ('orang', 298827),
#  ('us', 294711),
#  ('after', 293975),
#  ('from', 280314),
#  ('video', 279922),
#  ('says', 279377),
#  ('property', 273832),
#  ('about', 272092),
#  ('wanita', 267419),
#  ('raya', 264462),
#  ('rtb', 260748),
#  ('out', 260466),
#  ('news', 259064),
#  ('up', 258677),
#  ('lagi', 256625),
#  ('bakal', 255744),
#  ('over', 253570),
#  ('lelaki', 253324),
#  ('kini', 247105),
#  ('read', 245729),
#  ('bukan', 244913),
#  ('anwar', 243647),
#  ('his', 242001),
#  ('it', 239327),
#  ('petra', 237672),
#  ('mahu', 231719),
#  ('rumah', 231077),
#  ('all', 227245),
#  ('kongsi', 226476),
#  ('johor', 222524),
#  ('dua', 222317),
#  ('isu', 214441),
#  ('baru', 213537),
#  ('selepas', 212335),
#  ('lalu', 211968),
#  ('rakyat', 211718),
#  ('kami', 209092),
#  ('raja', 207908),
#  ('world', 205164)]

# %%
word_counts.most_common(100)
# Out:
# [('rm', 1874016),
#  ('to', 1575740),
#  ('in', 1485760),
#  ('for', 1364739),
#  ('di', 1178209),
#  ('the', 1115668),
#  ('of', 1088133),
#  ('s', 1050269),
#  ('sqm', 1022913),
#  ('sqft', 1022892),
#  ('properties', 976728),
#  ('malaysia', 919802),
#  ('more', 693704),
#  ('yang', 659794),
#  ('ini', 635270),
#  ('video', 631991),
#  ('news', 563769),
#  ('dengan', 508396),
#  ('a', 498495),
#  ('new', 477752),
#  ('dan', 462913),
#  ('untuk', 458248),
#  ('on', 454915),
#  ('ke', 432370),
#  ('berita', 427828),
#  ('and', 425206),
#  ('no', 422817),
#  ('tak', 414164),
#  ('rent', 408566),
#  ('dalam', 389925),
#  ('najib', 385717),
#  ('anak', 362569),
#  ('tidak', 354724),
#  ('is', 352756),
#  ('sale', 341295),
#  ('mahathir', 339233),
#  ('dunia', 326064),
#  ('lifestyle', 324680),
#  ('umno', 316934),
#  ('with', 300981),
#  ('tahun', 298081),
#  ('sukan', 292616),
#  ('negara', 291113),
#  ('pas', 277138),
#  ('jadi', 275003),
#  ('tv', 273781),
#  ('buat', 268337),
#  ('nasional', 261815),
#  ('saya', 261464),
#  ('rtb', 261208),
#  ('as', 256333),
#  ('m', 253828),
#  ('football', 253651),
#  ('home', 252373),
#  ('world', 251297),
#  ('at', 251054),
#  ('read', 245292),
#  ('us', 245171),
#  ('dr', 242053),
#  ('archives', 240225),
#  ('terkini', 239025),
#  ('hari', 232002),
#  ('says', 227379),
#  ('property', 227262),
#  ('be', 226092),
#  ('akan', 225498),
#  ('johor', 215602),
#  ('pada', 213014),
#  ('trending', 211518),
#  ('anwar', 211300),
#  ('lagi', 209326),
#  ('you', 209238),
#  ('not', 207374),
#  ('lalu', 206732),
#  ('kl', 202656),
#  ('kami', 200022),
#  ('jam', 198049),
#  ('entertainment', 197622),
#  ('lebih', 196917),
#  ('boleh', 196523),
#  ('isu', 196461),
#  ('utama', 195099),
#  ('nak', 191906),
#  ('orang', 191204),
#  ('it', 191095),
#  ('korang', 186482),
#  ('raja', 184775),
#  ('anda', 183868),
#  ('all', 182414),
#  ('pru', 182380),
#  ('hiburan', 182349),
#  ('ada', 181250),
#  ('mark', 180995),
#  ('by', 180758),
#  ('lelaki', 179276),
#  ('wanita', 178762),
#  ('perlu', 178241),
#  ('dari', 176530),
#  ('leo', 176261),
#  ('after', 176179)]

# %%
len([(word, count) for word, count in word_counts.most_common() if word not in word_1_grams])
# Out:
# 18958

# %%
[(word, count) for word, count in word_counts.most_common() if word not in word_1_grams and (word in ms_words or word not in eng_words_large)][:100]
# Out:
# [('sqm', 1022913),
#  ('sqft', 1022892),
#  ('jpg', 151044),
#  ('seagames', 35652),
#  ('ekoniaga', 26220),
#  ('eksentrik', 25636),
#  ('entertainmet', 19713),
#  ('fourthofficial', 17828),
#  ('australiaopen', 17826),
#  ('suganya', 17794),
#  ('mhtv', 17749),
#  ('myresipi', 16567),
#  ('suudu', 16528),
#  ('ebiz', 15616),
#  ('newsbriefs', 15502),
#  ('rojakdaily', 13137),
#  ('arenakereta', 13077),
#  ('amazingnara', 13077),
#  ('mybooks', 12878),
#  ('webtv', 12517),
#  ('ipa', 12387),
#  ('advancedsearch', 12386),
#  ('sgbagus', 12354),
#  ('aizam', 11727),
#  ('hiadiputra', 11178),
#  ('qibod', 9658),
#  ('gedjet', 9589),
#  ('shafika', 9448),
#  ('enewsletter', 9144),
#  ('natonline', 9041),
#  ('worldsbk', 9002),
#  ('onerror', 8521),
#  ('kathirasen', 8519),
#  ('mhcover', 8464),
#  ('iklaneka', 8276),
#  ('mhbreakfirst', 8009),
#  ('klasified', 6843),
#  ('rapsodi', 5976),
#  ('sukansinar', 5874),
#  ('gpsbestari', 5485),
#  ('kampusuols', 5483),
#  ('twitterdev', 5471),
#  ('hijabster', 4427),
#  ('terimakasihcikgu', 3724),
#  ('hmm', 3532),
#  ('movc', 3492),
#  ('blogserius', 3402),
#  ('sembanglebat', 3236),
#  ('español', 3232),
#  ('malaysiandigest', 3227),
#  ('utravel', 3044),
#  ('audiobuzz', 3022),
#  ('nyahkotak', 2582),
#  ('btw', 2482),
#  ('hazurin', 2374),
#  ('kelirulah', 2119),
#  ('rayakitasingalong', 2085),
#  ('yq', 1979),
#  ('chillax', 1860),
#  ('andrefinalx', 1843),
#  ('exponegaraku', 1746),
#  ('utbm', 1624),
#  ('montbéliard', 1624),
#  ('merrepak', 1410),
#  ('bumiarmada', 1396),
#  ('bahlol', 1343),
#  ('antiradang', 1340),
#  ('hazizi', 1316),
#  ('galaxynote', 1171),
#  ('arsip', 1105),
#  ('sinarharian', 1102),
#  ('epul', 1086),
#  ('bloomsvale', 1031),
#  ('skleroderma', 880),
#  ('hellboy', 874),
#  ('junho', 846),
#  ('producola', 835),
#  ('bieha', 819),
#  ('beddua', 812),
#  ('gir', 804),
#  ('itsycal', 773),
#  ('mengekek', 761),
#  ('salfishihah', 758),
#  ('alfatihah', 747),
#  ('meridap', 714),
#  ('kenyal', 686),
#  ('wanitough', 653),
#  ('mhcepuemas', 628),
#  ('mhlifestyle', 628),
#  ('mhcabar', 628),
#  ('jhams', 622),
#  ('submersão', 605),
#  ('img', 603),
#  ('forwardtogether', 601),
#  ('nanolitography', 581),
#  ('metronomik', 579),
#  ('polyamorous', 562),
#  ('kajiselidik', 555),
#  ('azyanshor', 545),
#  ('ttfga', 534)]

# %%
[word for word, _ in word_1_grams.most_common() if word not in word_counts]
# Out:
# ['energia']

# %%
sum(word_counts.values())
# Out:
# 168836600

# %%
word_counts['advancedsearch'] / sum(word_counts.values())
# Out:
# 7.336087080644837e-05

# %%
word_1_grams['energia']
# Out:
# 1

# %%
def similarity(n1, n2):
    return min(n1, n2) / max(n1, n2)

# %%
all_ms_words = set(word_counts.keys()).union(set(word_1_grams.keys()))

# %%
sum(word_counts.values()) / 1000 / 1000
# Out:
# 168.8366

# %%
sum(word_1_grams.values()) / 1000 / 1000
# Out:
# 219.384828

# %%
len(all_ms_words)
# Out:
# 96665

# %%
word_sim = Counter({word: similarity(word_counts[word], word_1_grams[word])
                    for word in all_ms_words
                    if (word not in eng_words_large) 
                    and (similarity(word_counts[word], word_1_grams[word]) > 0)
                    and (similarity(word_counts[word], word_1_grams[word]) < 1)
                    and (word_counts[word] > 160 or word_1_grams[word] > 210)
                   })
len(word_sim)
# Out:
# 15198

# %%
word_sim.most_common()[4000::-1]
# Out:
# [('lada', 0.7623947614593077),
#  ('ustazah', 0.7624286878565607),
#  ('menunggang', 0.7624336069531628),
#  ('ucapkan', 0.7625368731563422),
#  ('pekerjaan', 0.7625428168446504),
#  ('futsal', 0.7626774847870182),
#  ('dahulu', 0.762719428741446),
#  ('semangat', 0.7627469646107854),
#  ('muslimah', 0.7627705627705628),
#  ('chatime', 0.7627952755905512),
#  ('manjakan', 0.7628032345013477),
#  ('juruwang', 0.7628571428571429),
#  ('renjer', 0.7630057803468208),
#  ('berseorangan', 0.7630522088353414),
#  ('fitri', 0.7631086142322098),
#  ('pencegahan', 0.7631233595800525),
#  ('mendominasi', 0.7631578947368421),
#  ('menular', 0.7632311977715878),
#  ('ditunda', 0.7632612966601179),
#  ('comfortdelgro', 0.7633136094674556),
#  ('shafee', 0.7633644169513434),
#  ('propertyguru', 0.7634050081654872),
#  ('perlawanan', 0.7634458672875436),
#  ('mendebarkan', 0.7634803921568627),
#  ('mydin', 0.7635933806146572),
#  ('luqman', 0.7637260950030845),
#  ('ketokohan', 0.7637614678899083),
#  ('demokrat', 0.7637795275590551),
#  ('وانيتا', 0.7637795275590551),
#  ('mspo', 0.7637969094922737),
#  ('zarina', 0.7638244156690284),
#  ('ekonomi', 0.7638326158521145),
#  ('fahami', 0.7638423899047129),
#  ('perpecahan', 0.7639163047769444),
#  ('demonstrasi', 0.7639405204460966),
#  ('berbahaya', 0.764),
#  ('yuna', 0.7640232108317214),
#  ('diedar', 0.7640449438202247),
#  ('kemerdekaan', 0.764089427107592),
#  ('pertarungan', 0.7640931372549019),
#  ('mengaji', 0.7640949554896143),
#  ('petang', 0.7641122835775023),
#  ('cantiknya', 0.7641228939544104),
#  ('sorok', 0.7641484601210845),
#  ('berlegar', 0.764182424916574),
#  ('mengigau', 0.7641921397379913),
#  ('sarkas', 0.7642149191444966),
#  ('kupu', 0.7642487046632125),
#  ('ajal', 0.76426460559218),
#  ('koyak', 0.7643224699828474),
#  ('benarkah', 0.7643288774949643),
#  ('izara', 0.7643634522905594),
#  ('kulai', 0.7644539614561028),
#  ('bsh', 0.7644690488173125),
#  ('kapit', 0.7646249139710943),
#  ('pertelingkahan', 0.7647058823529411),
#  ('hodeidah', 0.7647058823529411),
#  ('syazwan', 0.764780673871583),
#  ('deloitte', 0.7648054145516074),
#  ('safiey', 0.7648712470482402),
#  ('inspektor', 0.7648791985857395),
#  ('kasar', 0.7649734647460197),
#  ('kita', 0.7650290087643501),
#  ('longkang', 0.7650889453621347),
#  ('terbalik', 0.7650971468580431),
#  ('pengadilan', 0.7651122625215889),
#  ('takaful', 0.7651917404129793),
#  ('diserbu', 0.7652089943440474),
#  ('usim', 0.7652558703875526),
#  ('sepanyol', 0.7653639618138425),
#  ('sufian', 0.7653842193774238),
#  ('menyeluruh', 0.765427643450018),
#  ('kaamatan', 0.7654320987654321),
#  ('bendul', 0.7654867256637168),
#  ('nrd', 0.7655571635311144),
#  ('apalah', 0.7656458055925432),
#  ('bnc', 0.7656903765690377),
#  ('berlubang', 0.7657303370786517),
#  ('bendahari', 0.7657342657342657),
#  ('ketulan', 0.7657378740970072),
#  ('hamidin', 0.7657580919931857),
#  ('lazat', 0.7658113480303578),
#  ('hilmi', 0.7660377358490567),
#  ('terhibur', 0.7660575357336711),
#  ('marhaen', 0.7660626029654036),
#  ('eid', 0.7660818713450293),
#  ('sepasukan', 0.7661469933184856),
#  ('terjerat', 0.7663551401869159),
#  ('kesinambungan', 0.766367137355584),
#  ('diboikot', 0.7664543524416136),
#  ('ecp', 0.7664670658682635),
#  ('berduri', 0.7666666666666667),
#  ('hujan', 0.7667068549776094),
#  ('nfc', 0.766984505363528),
#  ('jeti', 0.7670837343599615),
#  ('azil', 0.767097966728281),
#  ('aeril', 0.7671028037383177),
#  ('penternak', 0.7671081677704195),
#  ('ڤرچوما', 0.7671232876712328),
#  ('diperbaharui', 0.7671232876712328),
#  ('diraba', 0.7672413793103449),
#  ('semenyih', 0.7674418604651163),
#  ('jkm', 0.7674745345978222),
#  ('berwaspada', 0.7676240208877284),
#  ('kilauan', 0.7676886792452831),
#  ('baharom', 0.7677165354330708),
#  ('rumput', 0.7677183356195701),
#  ('berhelah', 0.7677261613691931),
#  ('ketulusan', 0.7677419354838709),
#  ('irb', 0.7677496991576414),
#  ('mukim', 0.7678100263852242),
#  ('apartmen', 0.7678122380553227),
#  ('autistik', 0.7678207739307535),
#  ('terhina', 0.7678381256656017),
#  ('dikritik', 0.7679278591535855),
#  ('temasya', 0.7679558011049724),
#  ('hannymaru', 0.768),
#  ('ranggup', 0.7680097680097681),
#  ('pelawak', 0.7680240320427236),
#  ('rohingya', 0.7680273562727078),
#  ('ecoworld', 0.7680608365019012),
#  ('jempol', 0.7681159420289855),
#  ('ffm', 0.7681623931623932),
#  ('kredit', 0.7682412267160647),
#  ('kelaparan', 0.7682926829268293),
#  ('merangkak', 0.7683257918552037),
#  ('lalai', 0.7683284457478006),
#  ('kaspersky', 0.7684563758389261),
#  ('penyedia', 0.7684989429175476),
#  ('ics', 0.7685185185185185),
#  ('powerbank', 0.768595041322314),
#  ('khasiat', 0.7687771570453135),
#  ('berubat', 0.7688053097345132),
#  ('cuai', 0.7688656858092074),
#  ('jumlah', 0.7689780761265443),
#  ('kudat', 0.7692307692307693),
#  ('kesabaran', 0.7692926045016077),
#  ('perihal', 0.7693103448275862),
#  ('nampaknya', 0.7693244065733414),
#  ('balestier', 0.7693877551020408),
#  ('dangkal', 0.7694805194805194),
#  ('نڬارا', 0.7695390781563126),
#  ('alahan', 0.7695560253699789),
#  ('ewal', 0.7695652173913043),
#  ('coretan', 0.769588828549263),
#  ('azrinaz', 0.7696148359486448),
#  ('penganjur', 0.7696411251212415),
#  ('mendaki', 0.7696414950419527),
#  ('meniru', 0.7696793002915452),
#  ('sikit', 0.7696894188840437),
#  ('istiqamah', 0.769901083372586),
#  ('puigdemont', 0.7699115044247787),
#  ('widodo', 0.7699530516431925),
#  ('terendak', 0.7699530516431925),
#  ('syawal', 0.7701946567893451),
#  ('kesah', 0.7702702702702703),
#  ('ditakuti', 0.7702702702702703),
#  ('fairprice', 0.7703081232492998),
#  ('hampiri', 0.7704181320828448),
#  ('terseret', 0.7704918032786885),
#  ('عيدالفطري', 0.7705627705627706),
#  ('pengacara', 0.7705656975433852),
#  ('asnaf', 0.7705729589352378),
#  ('narita', 0.7706666666666667),
#  ('jpn', 0.7706734867860188),
#  ('tendong', 0.7706766917293233),
#  ('pendengar', 0.7707581227436823),
#  ('mln', 0.7708006279434851),
#  ('tariq', 0.7708333333333334),
#  ('rosnah', 0.7708333333333334),
#  ('pujuk', 0.7709143968871596),
#  ('hyflux', 0.770940170940171),
#  ('uitm', 0.7709765467044076),
#  ('radhi', 0.7709963484611372),
#  ('ternyata', 0.7710706150341685),
#  ('rentetan', 0.7710843373493976),
#  ('rela', 0.7712931417567768),
#  ('hahaha', 0.7713310580204779),
#  ('kunyah', 0.7713498622589532),
#  ('apandi', 0.7713972201901975),
#  ('koma', 0.7714065312419646),
#  ('mayat', 0.7714731285988484),
#  ('makmur', 0.7714870395634379),
#  ('rektor', 0.7714884696016772),
#  ('benua', 0.7714953271028038),
#  ('sunyi', 0.771505376344086),
#  ('rrg', 0.771513353115727),
#  ('panca', 0.7715231788079471),
#  ('menipu', 0.7716838699738099),
#  ('sebanyak', 0.7717794550339004),
#  ('persaudaraan', 0.7718120805369127),
#  ('waras', 0.7718715393133998),
#  ('komprehensif', 0.7719594594594594),
#  ('penguatkuasaan', 0.7719844357976654),
#  ('umt', 0.7720261437908497),
#  ('lutsinar', 0.7720364741641338),
#  ('disekat', 0.7720745493431103),
#  ('berbaloi', 0.7720759923583104),
#  ('paksaan', 0.772189349112426),
#  ('jepun', 0.7722162452931683),
#  ('terpadam', 0.7722342733188721),
#  ('zaquan', 0.7722908093278463),
#  ('najmuddin', 0.7723214285714286),
#  ('zayan', 0.7723577235772358),
#  ('kepelbagaian', 0.7724236641221374),
#  ('kok', 0.7724485125858124),
#  ('lusuh', 0.7725),
#  ('paria', 0.7725118483412322),
#  ('motifnya', 0.7725118483412322),
#  ('pafa', 0.7726005575467941),
#  ('mangkhut', 0.7726235741444867),
#  ('fattah', 0.7726820533227219),
#  ('pembaziran', 0.772801747678864),
#  ('umur', 0.7730748624031951),
#  ('ipcmc', 0.7730753728335349),
#  ('jpj', 0.7732049036777583),
#  ('rehatkan', 0.7732160312805474),
#  ('menyusut', 0.7733333333333333),
#  ('hasutan', 0.7733540158566011),
#  ('komtar', 0.7735042735042735),
#  ('pengukuhan', 0.7735191637630662),
#  ('pantang', 0.7735449735449735),
#  ('sharnaaz', 0.7735984495011127),
#  ('kavadi', 0.7736280487804879),
#  ('penumpang', 0.7736557756624646),
#  ('kbc', 0.7736625514403292),
#  ('haniza', 0.7736842105263158),
#  ('renggang', 0.7737430167597765),
#  ('murahan', 0.7737757992715499),
#  ('ropol', 0.7738095238095238),
#  ('siasah', 0.7738095238095238),
#  ('praktis', 0.7738095238095238),
#  ('lengang', 0.7738693467336684),
#  ('namron', 0.7738970588235294),
#  ('tawau', 0.7739130434782608),
#  ('paket', 0.773972602739726),
#  ('termurah', 0.7740345110928513),
#  ('melatah', 0.7740485465987413),
#  ('batin', 0.774100124120811),
#  ('subuh', 0.7741100323624596),
#  ('dipenjara', 0.7741529812102382),
#  ('khasif', 0.7741935483870968),
#  ('mersing', 0.7743869209809264),
#  ('dibela', 0.774390243902439),
#  ('htc', 0.7744249319812021),
#  ('hairul', 0.7744461102781942),
#  ('sinergi', 0.7744565217391305),
#  ('raus', 0.774468085106383),
#  ('izzue', 0.7745524915336236),
#  ('dpim', 0.7745664739884393),
#  ('bermotor', 0.774617067833698),
#  ('ronaldinho', 0.774617067833698),
#  ('zii', 0.7746741154562383),
#  ('harian', 0.7746765177280013),
#  ('spotify', 0.7746926371045725),
#  ('vsp', 0.7747747747747747),
#  ('melonjak', 0.7748287671232876),
#  ('uiam', 0.7748460861917327),
#  ('gelinya', 0.774869109947644),
#  ('federalisme', 0.7749419953596288),
#  ('hidung', 0.7749763033175355),
#  ('lokap', 0.7751060820367751),
#  ('pangkor', 0.7751091703056768),
#  ('klasikal', 0.7751196172248804),
#  ('kegembiraan', 0.7751646284101599),
#  ('gejala', 0.7752040010529087),
#  ('bharu', 0.775273799494524),
#  ('terpisah', 0.7753378378378378),
#  ('terganggu', 0.7754629629629629),
#  ('jahat', 0.7754752526117485),
#  ('jazlan', 0.7755102040816326),
#  ('awasi', 0.7755485893416928),
#  ('ktm', 0.7757009345794392),
#  ('nba', 0.7757475083056479),
#  ('punggung', 0.7757548845470693),
#  ('agc', 0.7758097165991903),
#  ('unimas', 0.775811209439528),
#  ('buatmu', 0.7758620689655172),
#  ('muar', 0.7758887171561051),
#  ('dhia', 0.7759259259259259),
#  ('iqram', 0.775990099009901),
#  ('tangisan', 0.7760683760683761),
#  ('dihadkan', 0.7761194029850746),
#  ('kubra', 0.7762525737817433),
#  ('gimrama', 0.776255707762557),
#  ('sunwolves', 0.776255707762557),
#  ('ميت', 0.7763157894736842),
#  ('fanatik', 0.7763157894736842),
#  ('cert', 0.7763713080168776),
#  ('fizo', 0.7764243614931238),
#  ('pernafasan', 0.7764390896921017),
#  ('sathianathan', 0.7764471057884231),
#  ('موريد', 0.7764705882352941),
#  ('jerayawara', 0.7765151515151515),
#  ('dilabel', 0.7765500306936771),
#  ('hampa', 0.7766143106457243),
#  ('banget', 0.7766233766233767),
#  ('kemain', 0.7766990291262136),
#  ('migrain', 0.7766990291262136),
#  ('dikhianati', 0.7767106842737095),
#  ('tuas', 0.7767408470926059),
#  ('habis', 0.7767612402548859),
#  ('makna', 0.7768173758865248),
#  ('mendalam', 0.7768281101614435),
#  ('tempang', 0.7768595041322314),
#  ('samad', 0.7768991377990919),
#  ('توجوه', 0.7769230769230769),
#  ('ziana', 0.7769480061998028),
#  ('elok', 0.7770297837617299),
#  ('dibimbangi', 0.7770491803278688),
#  ('badai', 0.7770975873244509),
#  ('کريتا', 0.7771084337349398),
#  ('zeti', 0.7771574784833682),
#  ('ditekan', 0.7771883289124668),
#  ('masin', 0.7772963604852686),
#  ('pemilu', 0.7773037542662116),
#  ('makanlah', 0.77734375),
#  ('qazaf', 0.7774294670846394),
#  ('aaisyah', 0.7774615822424588),
#  ('shiha', 0.7774750227066304),
#  ('terkubur', 0.777535441657579),
#  ('sumbing', 0.7775700934579439),
#  ('geram', 0.7779951100244499),
#  ('berkeyakinan', 0.7780898876404494),
#  ('prosedur', 0.7781103035485251),
#  ('demokrasi', 0.7782172193489504),
#  ('penghormatan', 0.7782580222658808),
#  ('pesara', 0.7782982045277127),
#  ('politikus', 0.7783094098883573),
#  ('cergas', 0.7783157894736842),
#  ('jsjk', 0.7783171521035599),
#  ('punyai', 0.7783328950828293),
#  ('gajah', 0.7783690137359238),
#  ('exco', 0.7783951179524546),
#  ('kononnya', 0.7784540474741327),
#  ('ranau', 0.7784810126582279),
#  ('pemerintah', 0.778486186038908),
#  ('keutamaan', 0.7786431291104188),
#  ('tokong', 0.7786509495743288),
#  ('سينديكيت', 0.778816199376947),
#  ('jojie', 0.7788461538461539),
#  ('berkat', 0.7790228597041685),
#  ('parlimen', 0.7790676012388515),
#  ('rakyatnya', 0.7791044776119403),
#  ('subramaniam', 0.7792207792207793),
#  ('projektor', 0.7792387543252595),
#  ('afiq', 0.7792642140468228),
#  ('kerteh', 0.7792642140468228),
#  ('fih', 0.7793427230046949),
#  ('gerakan', 0.7793461690474847),
#  ('undian', 0.7794181502388189),
#  ('waris', 0.7794916358896372),
#  ('tiba', 0.7794991351432654),
#  ('perusuh', 0.7795152462861611),
#  ('bumiputera', 0.7795483664317745),
#  ('penularan', 0.7796343001261034),
#  ('rmk', 0.779651795429815),
#  ('pastu', 0.7796934865900383),
#  ('spedy', 0.7797979797979798),
#  ('farid', 0.7798031352533722),
#  ('beranak', 0.7798719772403983),
#  ('fauzi', 0.7799227799227799),
#  ('kucaimars', 0.78),
#  ('shahrel', 0.78),
#  ('ڤكرجا', 0.78),
#  ('akuarium', 0.7800829875518672),
#  ('rahimi', 0.7801418439716312),
#  ('berpolitik', 0.7802495930548019),
#  ('kemudian', 0.7802874743326489),
#  ('psg', 0.7802898550724637),
#  ('dibubarkan', 0.7803030303030303),
#  ('bermotosikal', 0.7803379416282642),
#  ('berhormat', 0.7803468208092486),
#  ('linangan', 0.7803602556653109),
#  ('madius', 0.7804878048780488),
#  ('uncang', 0.7804878048780488),
#  ('jkkk', 0.7805486284289277),
#  ('monyet', 0.7806417674907943),
#  ('dirotan', 0.7807228915662651),
#  ('lusoh', 0.7807486631016043),
#  ('hidup', 0.7808911147569294),
#  ('perkara', 0.7809565217391304),
#  ('bln', 0.7809778968519759),
#  ('bercelaru', 0.781021897810219),
#  ('sgh', 0.7810858143607706),
#  ('lencana', 0.7811120917917035),
#  ('dilupakan', 0.7812173913043479),
#  ('terbatal', 0.78125),
#  ('aidilfitri', 0.781351158195653),
#  ('gempa', 0.7816156958280768),
#  ('salib', 0.7817258883248731),
#  ('hentam', 0.7818181818181819),
#  ('alhadad', 0.7819365337672904),
#  ('penganiayaan', 0.7819548872180451),
#  ('rambang', 0.7820276497695853),
#  ('beserah', 0.7821011673151751),
#  ('zaki', 0.7821122740247384),
#  ('berkompromi', 0.7821229050279329),
#  ('diumumkan', 0.7822314049586777),
#  ('asyraff', 0.7822349570200573),
#  ('buyung', 0.7824267782426778),
#  ('ڤراتوس', 0.7824561403508772),
#  ('maritim', 0.7825168918918919),
#  ('ditukar', 0.7825284527837588),
#  ('bestarinet', 0.782608695652174),
#  ('kaduk', 0.782608695652174),
#  ('pepejal', 0.782608695652174),
#  ('tertipu', 0.7826271186440678),
#  ('unimap', 0.7827145465611686),
#  ('bersekedudukan', 0.7828200972447326),
#  ('jauhkan', 0.782967032967033),
#  ('seluas', 0.7829716193656093),
#  ('suaranya', 0.7829787234042553),
#  ('nano', 0.7830739299610895),
#  ('xpdc', 0.7830923248053393),
#  ('كيلوڬرم', 0.7831325301204819),
#  ('zizie', 0.7831891688604738),
#  ('kementerian', 0.7832085718479378),
#  ('berkahwin', 0.7833618233618234),
#  ('marcote', 0.7834036568213784),
#  ('comel', 0.7834095528455285),
#  ('menunjuk', 0.7835703001579779),
#  ('vigneswaran', 0.783625730994152),
#  ('semput', 0.7836879432624113),
#  ('surau', 0.7837333954789093),
#  ('tabungan', 0.7837465564738292),
#  ('erra', 0.7837958818263205),
#  ('syamsul', 0.7838012262020007),
#  ('berterusan', 0.7838193378645034),
#  ('deepavali', 0.7838397790055248),
#  ('ghaib', 0.7838427947598253),
#  ('lasak', 0.7838652927871325),
#  ('oth', 0.7839195979899497),
#  ('shila', 0.7839745048941498),
#  ('alcatel', 0.7839805825242718),
#  ('motorsports', 0.7840065058281377),
#  ('rewcastle', 0.7840555860303529),
#  ('lebah', 0.7840587902769927),
#  ('jengka', 0.7840909090909091),
#  ('dikurangkan', 0.7841866493843163),
#  ('zalim', 0.7842323651452282),
#  ('zizan', 0.7843045112781954),
#  ('sarimah', 0.7843590930124942),
#  ('pembuli', 0.7843642611683849),
#  ('padanan', 0.7844036697247706),
#  ('konsisten', 0.7844935389745727),
#  ('perenang', 0.7845433255269321),
#  ('axiata', 0.784554312522555),
#  ('ipic', 0.7845559845559845),
#  ('karnival', 0.7845622119815668),
#  ('pacquiao', 0.784648765934364),
#  ('amirul', 0.7846678023850086),
#  ('melancong', 0.7847863741339491),
#  ('gendang', 0.7848324514991182),
#  ('dpmm', 0.7849293563579278),
#  ('tersinggung', 0.7849462365591398),
#  ('streamyx', 0.7849802371541502),
#  ('alik', 0.785012285012285),
#  ('thinq', 0.785039941902687),
#  ('lakonan', 0.785067558155732),
#  ('lancang', 0.7850746268656716),
#  ('haliza', 0.7851239669421488),
#  ('bertaubat', 0.78515625),
#  ('pubg', 0.7852564102564102),
#  ('gemuk', 0.7852582704585026),
#  ('agong', 0.7854858198876964),
#  ('sinarlive', 0.7854984894259819),
#  ('disemadi', 0.7855297157622739),
#  ('diusung', 0.7857142857142857),
#  ('aksi', 0.7857740585774059),
#  ('peragut', 0.7857911733046287),
#  ('kesian', 0.7858870081336558),
#  ('bloomberg', 0.7859237536656891),
#  ('ppn', 0.7860262008733624),
#  ('sebiji', 0.786046511627907),
#  ('penjual', 0.7860689840289894),
#  ('diselenggara', 0.7861111111111111),
#  ('prejudis', 0.7862318840579711),
#  ('olahraga', 0.7862444334487877),
#  ('سوسڤيک', 0.7863247863247863),
#  ('tfc', 0.786344537815126),
#  ('dulu', 0.7863672391017174),
#  ('sejam', 0.7863760217983651),
#  ('kekasihnya', 0.7864321608040201),
#  ('cfm', 0.7865030674846626),
#  ('sendiri', 0.7865069439873627),
#  ('haiza', 0.7865168539325843),
#  ('mengoptimasikan', 0.7865497076023392),
#  ('pelacur', 0.7865972674040338),
#  ('rom', 0.7866149369544132),
#  ('oppa', 0.7866666666666666),
#  ('kpi', 0.7867203219315896),
#  ('mpk', 0.7867902665121669),
#  ('gst', 0.7868305191349364),
#  ('progres', 0.7868852459016393),
#  ('bpr', 0.7868852459016393),
#  ('esscom', 0.7869994196169472),
#  ('angkuh', 0.7870905587668593),
#  ('ltdl', 0.7871520342612419),
#  ('lebron', 0.7873303167420814),
#  ('igauan', 0.7874015748031497),
#  ('bashar', 0.7874186550976139),
#  ('menentu', 0.7874331550802139),
#  ('marsiling', 0.7874396135265701),
#  ('poket', 0.7875278396436526),
#  ('karektor', 0.7875457875457875),
#  ('balkisyh', 0.7875647668393783),
#  ('berulat', 0.7876230661040787),
#  ('hkl', 0.7876506024096386),
#  ('mustapha', 0.78786430960344),
#  ('jenazah', 0.7878704113224237),
#  ('cilik', 0.7879147387985922),
#  ('bagai', 0.7879261363636364),
#  ('mariah', 0.7879616963064295),
#  ('sepadan', 0.7879924953095685),
#  ('otak', 0.7880567792462065),
#  ('ketengah', 0.788135593220339),
#  ('bersedekah', 0.7882096069868996),
#  ('haziq', 0.7884272644461167),
#  ('madu', 0.7884914463452566),
#  ('kerian', 0.7885010266940452),
#  ('pusing', 0.7885657959586003),
#  ('menyengat', 0.78860103626943),
#  ('ڤد', 0.7886178861788617),
#  ('halus', 0.788628762541806),
#  ('nst', 0.7887029288702929),
#  ('mamat', 0.7887931034482759),
#  ('tersendiri', 0.7888395688015218),
#  ('ipp', 0.7888888888888889),
#  ('gerhana', 0.7889305816135085),
#  ('ketupat', 0.7890127388535032),
#  ('wsj', 0.7891290111329404),
#  ('menurun', 0.7892436974789916),
#  ('ioniq', 0.7892561983471075),
#  ('karpal', 0.7893065113816834),
#  ('miti', 0.789308176100629),
#  ('progresif', 0.7893175074183977),
#  ('ptptn', 0.7894301510600322),
#  ('rangkumi', 0.7894736842105263),
#  ('semenya', 0.7894736842105263),
#  ('kondominium', 0.7895752895752896),
#  ('aj', 0.789587852494577),
#  ('kenyataan', 0.789649140858113),
#  ('azwan', 0.7896543831540398),
#  ('baguslah', 0.7897623400365631),
#  ('skuasy', 0.789815817984832),
#  ('stabil', 0.7898317221625493),
#  ('konmari', 0.7899543378995434),
#  ('vesak', 0.7899686520376176),
#  ('gelora', 0.7899686520376176),
#  ('azman', 0.79),
#  ('ruzaini', 0.7901459854014599),
#  ('peja', 0.7901785714285714),
#  ('digelar', 0.7901852453688658),
#  ('kisahlah', 0.7903225806451613),
#  ('vellu', 0.790356394129979),
#  ('berlawan', 0.7904085257548845),
#  ('hael', 0.7905147484094852),
#  ('tikus', 0.7905431809300508),
#  ('kelate', 0.7905686546463245),
#  ('daif', 0.7906008328375966),
#  ('pacman', 0.790625),
#  ('lampin', 0.790633608815427),
#  ('sipitang', 0.7906976744186046),
#  ('dipendekkan', 0.7908653846153846),
#  ('nizar', 0.7908979089790897),
#  ('persoalan', 0.7909722222222222),
#  ('alam', 0.7909855230133509),
#  ('menghasut', 0.790986790986791),
#  ('kreatif', 0.7910286677908938),
#  ('menjahanamkan', 0.7911184210526315),
#  ('wilshere', 0.7911227154046997),
#  ('bermutu', 0.7911275415896488),
#  ('merpati', 0.7911392405063291),
#  ('amalina', 0.7912148502113582),
#  ('pknp', 0.7912322274881517),
#  ('penyelam', 0.7912584777694047),
#  ('melalak', 0.7912621359223301),
#  ('mahmood', 0.7912713472485768),
#  ('berkhidmat', 0.7912729294052251),
#  ('penangites', 0.791340206185567),
#  ('keping', 0.7914614121510674),
#  ('najibkuala', 0.7914691943127962),
#  ('tertekan', 0.7915676959619953),
#  ('goyah', 0.7915936952714536),
#  ('pameran', 0.791700288184438),
#  ('persefahaman', 0.7917034421888791),
#  ('kinabatangan', 0.7917485265225933),
#  ('petik', 0.7918296392872664),
#  ('ghosn', 0.7918454935622318),
#  ('nanti', 0.7919962408959198),
#  ('takata', 0.792),
#  ('fynn', 0.7921455938697318),
#  ('reezal', 0.7921810699588477),
#  ('kesetiaan', 0.7921903052064632),
#  ('menyepi', 0.7922077922077922),
#  ('terbengkalai', 0.7922705314009661),
#  ('dugaan', 0.7923559612093554),
#  ('geng', 0.7924469736161407),
#  ('menderma', 0.7924528301886793),
#  ('izzmad', 0.7925718290119131),
#  ('tiz', 0.79265493496557),
#  ('thaksin', 0.7926829268292683),
#  ('benq', 0.7927631578947368),
#  ('aini', 0.7927927927927928),
#  ('terisi', 0.7927927927927928),
#  ('integriti', 0.7928248222365869),
#  ('tuai', 0.7928331466965286),
#  ('sifir', 0.7928388746803069),
#  ('hady', 0.7928934010152284),
#  ('berjinak', 0.7928994082840237),
#  ('idlib', 0.7931338028169014),
#  ('terapi', 0.7931379080612925),
#  ('ribut', 0.7932540022258369),
#  ('elakkan', 0.7932900432900433),
#  ('miera', 0.7933130699088146),
#  ('waheeda', 0.7933723196881092),
#  ('namun', 0.7934052195655571),
#  ('uia', 0.7934426229508197),
#  ('asus', 0.793515592801209),
#  ('acik', 0.7935483870967742),
#  ('mpv', 0.7935548841893253),
#  ('gce', 0.793563579277865),
#  ('sepak', 0.7935891605741537),
#  ('jpnin', 0.7935943060498221),
#  ('sembawang', 0.793709528214616),
#  ('kfa', 0.79375),
#  ('menakjubkan', 0.7937625754527163),
#  ('sopan', 0.7939115728436821),
#  ('cuma', 0.7939229603636654),
#  ('azraa', 0.7940199335548173),
#  ('tertuduh', 0.794054054054054),
#  ('perhitungan', 0.7940594059405941),
#  ('hongmeng', 0.7940987812700449),
#  ('hazwan', 0.7941176470588235),
#  ('nombor', 0.7941332203748809),
#  ('terpukau', 0.7941747572815534),
#  ('duathlon', 0.7941888619854721),
#  ('dipulangkan', 0.794251134644478),
#  ('jerami', 0.7942583732057417),
#  ('konsulat', 0.7944199706314243),
#  ('ruu', 0.7944414365637972),
#  ('habuan', 0.7945034353529045),
#  ('icc', 0.7945662535748331),
#  ('guaido', 0.7947154471544715),
#  ('pendidikan', 0.7947504959560506),
#  ('kallang', 0.7948051948051948),
#  ('mengukuhkan', 0.7948207171314741),
#  ('beretika', 0.7948717948717948),
#  ('niena', 0.7948990435706695),
#  ('rebung', 0.795071335927367),
#  ('doktor', 0.7950792848005236),
#  ('rafizi', 0.7951509484370826),
#  ('cuepacs', 0.7951570680628273),
#  ('batasan', 0.7953795379537953),
#  ('biar', 0.7953810623556582),
#  ('syukur', 0.7954231433506045),
#  ('ون', 0.7955271565495208),
#  ('mustafa', 0.7955508474576272),
#  ('pdp', 0.7955706984667802),
#  ('konsortium', 0.7957198443579766),
#  ('muntah', 0.7958135860979463),
#  ('kesungguhan', 0.795880149812734),
#  ('zulfadli', 0.7960725075528701),
#  ('bilal', 0.7961579509071505),
#  ('khinzir', 0.7961783439490446),
#  ('petrosaudi', 0.7962577962577962),
#  ('camora', 0.7962962962962963),
#  ('rantau', 0.7964639381189171),
#  ('kutty', 0.7965517241379311),
#  ('pencemaran', 0.7965657047460053),
#  ('bicara', 0.7966316417020642),
#  ('riak', 0.7967067764407854),
#  ('ketangkasan', 0.796736913664174),
#  ('payudara', 0.7968006917423259),
#  ('tertib', 0.796875),
#  ('nfcorp', 0.7970183486238532),
#  ('bersatu', 0.7970297693245942),
#  ('seberat', 0.797045101088647),
#  ('sirim', 0.7970644543714104),
#  ('dimaafkan', 0.7970749542961609),
#  ('berkabung', 0.7971014492753623),
#  ('harussani', 0.7971014492753623),
#  ('sekeliling', 0.7971311475409836),
#  ('warak', 0.7974137931034483),
#  ('pengsan', 0.7974855589534489),
#  ('pergaulan', 0.7976190476190477),
#  ('ayda', 0.7976372480889506),
#  ('membawang', 0.797650827549386),
#  ('masyair', 0.7977099236641222),
#  ('berpasukan', 0.797723292469352),
#  ('dicop', 0.797752808988764),
#  ('rajin', 0.797940797940798),
#  ('mxm', 0.7980132450331126),
#  ('miang', 0.7980535279805353),
#  ('cepatlah', 0.7981651376146789),
#  ('lesu', 0.7982565379825654),
#  ('obsesi', 0.7982583454281568),
#  ('pedih', 0.7982758620689655),
#  ('husam', 0.7982770385533947),
#  ('huruf', 0.7983193277310925),
#  ('noraniza', 0.7983501374885427),
#  ('faezah', 0.7984009137635637),
#  ('kuartet', 0.7984189723320159),
#  ('waze', 0.7985480943738656),
#  ('shahnon', 0.7987261146496816),
#  ('skuter', 0.7988215488215489),
#  ('membebel', 0.7988826815642458),
#  ('vernakular', 0.7989203778677463),
#  ('penyedut', 0.7989276139410187),
#  ('baiknya', 0.7989652623798965),
#  ('sifar', 0.7990535129231889),
#  ('deepika', 0.7990909090909091),
#  ('dedikasi', 0.7991399390790181),
#  ('naratif', 0.7991701244813278),
#  ('رعيت', 0.7992125984251969),
#  ('kelian', 0.7992625972961901),
#  ('dilulus', 0.7992700729927007),
#  ('melaram', 0.7992733878292462),
#  ('entiti', 0.7993421052631579),
#  ('jajaran', 0.7993920972644377),
#  ('berdakwah', 0.7994169096209912),
#  ('pemerhati', 0.7996001999000499),
#  ('zabeeh', 0.7996422182468694),
#  ('farmasi', 0.7997145575642245),
#  ('ismee', 0.7998075072184793),
#  ('hefny', 0.7998436278342455),
#  ('berkopiah', 0.8),
#  ('hilman', 0.8),
#  ('uthm', 0.8),
#  ('karak', 0.8),
#  ('dipukau', 0.8),
#  ('imunisasi', 0.8),
#  ('sampah', 0.8000634048399028),
#  ('bertanggungjawab', 0.8002607561929596),
#  ('berulang', 0.8002808988764045),
#  ('holistik', 0.8002936857562408),
#  ('syahmi', 0.8003300330033003),
#  ('mengapa', 0.8004040744170384),
#  ('psle', 0.8004434589800443),
#  ('falsafah', 0.8004459308807135),
#  ('jijik', 0.8004942709503482),
#  ('ditolak', 0.8005115089514067),
#  ('pendatang', 0.8005142165759226),
#  ('pensiangan', 0.8005181347150259),
#  ('jejambat', 0.8005865102639296),
#  ('menggemparkan', 0.8006379585326954),
#  ('ctos', 0.8007380073800738),
#  ('licin', 0.80078125),
#  ('kantoi', 0.800792864222002),
#  ('juruhebah', 0.8008298755186722),
#  ('esports', 0.8008678881388621),
#  ('ungkap', 0.8008752735229759),
#  ('lekat', 0.8009153318077803),
#  ('populis', 0.8009868421052632),
#  ('akrab', 0.8009888751545118),
#  ('diperhalusi', 0.8010033444816054),
#  ('langsung', 0.8010088456758535),
#  ('eropah', 0.8010255266971352),
#  ('bungkus', 0.8010630220197419),
#  ('kerakyatan', 0.8010768770565361),
#  ('suhakam', 0.8011882028431997),
#  ('dacing', 0.8012170385395537),
#  ('asbab', 0.8013245033112583),
#  ('migran', 0.8013245033112583),
#  ('utama', 0.8013367572360699),
#  ('ditangguhkan', 0.8013624955181069),
#  ('kesat', 0.8015503875968992),
#  ('uber', 0.8015803336259877),
#  ('daulah', 0.8016032064128257),
#  ('olahragawan', 0.8016877637130801),
#  ('lenovo', 0.801740506329114),
#  ('arnab', 0.8017699115044248),
#  ('mustafar', 0.8017751479289941),
#  ('aazief', 0.8018018018018018),
#  ('afc', 0.8018204385601986),
#  ('hp', 0.8019109764623631),
#  ('zizi', 0.8019617001401215),
#  ('tealive', 0.8020703933747412),
#  ('diracun', 0.8021201413427562),
#  ('kacir', 0.8022284122562674),
#  ('assabiqun', 0.8022657054582905),
#  ('jmm', 0.8022747156605424),
#  ('lekor', 0.8023255813953488),
#  ('leclerc', 0.8023255813953488),
#  ('psm', 0.8025714285714286),
#  ('zaharie', 0.8025751072961373),
#  ('huri', 0.8026315789473685),
#  ('gelombang', 0.8026567735758736),
#  ('wak', 0.8026704146170063),
#  ('perasuah', 0.802675585284281),
#  ('terkorban', 0.8027274136060747),
#  ('skrol', 0.8028169014084507),
#  ('zafuan', 0.8028169014084507),
#  ('hadis', 0.802827965435978),
#  ('saat', 0.80286337123667),
#  ('pencerahan', 0.802962962962963),
#  ('gaung', 0.8029719317556412),
#  ('fizikal', 0.8029875323453305),
#  ('payung', 0.8032445923460898),
#  ('kekebalan', 0.8032490974729242),
#  ('payoh', 0.8034042553191489),
#  ('insya', 0.8034188034188035),
#  ('pemandangan', 0.8034596981965403),
#  ('ekspedisi', 0.8034602076124567),
#  ('bintan', 0.8034682080924855),
#  ('awalnya', 0.8035714285714286),
#  ('merepek', 0.8035837353549277),
#  ('golek', 0.8037190082644629),
#  ('dagang', 0.8037620064034151),
#  ('gemparkan', 0.8037803780378038),
#  ('yala', 0.8038147138964578),
#  ('zverev', 0.8038379530916845),
#  ('pemancar', 0.8038674033149171),
#  ('keunikan', 0.8039361860742508),
#  ('menjawab', 0.8039532069382815),
#  ('pembentangan', 0.8040540540540541),
#  ('oksigen', 0.8040816326530612),
#  ('imigresen', 0.8041071069055769),
#  ('kohli', 0.8041237113402062),
#  ('ratusan', 0.8041966426858513),
#  ('keliru', 0.8042131350681536),
#  ('kontemporari', 0.8042659974905897),
#  ('نلاين', 0.8042813455657493),
#  ('sph', 0.804552770751897),
#  ('dipersoal', 0.8045830681094844),
#  ('hackathon', 0.8047058823529412),
#  ('hatinya', 0.8047945205479452),
#  ('penembak', 0.8048128342245989),
#  ('trw', 0.8048582995951417),
#  ('dengannya', 0.8048780487804879),
#  ('angah', 0.8049426301853486),
#  ('iktibar', 0.804945054945055),
#  ('nedim', 0.8049751243781095),
#  ('realiti', 0.8050058207217695),
#  ('berguru', 0.8052325581395349),
#  ('telur', 0.8052616528452959),
#  ('uyaina', 0.8053259871441689),
#  ('sekawan', 0.8054982817869416),
#  ('kesederhanaan', 0.8055555555555556),
#  ('بايي', 0.8056155507559395),
#  ('aidilfitiri', 0.8057851239669421),
#  ('ترماسوق', 0.8058252427184466),
#  ('للاكي', 0.8058455114822547),
#  ('ngeri', 0.8058461538461539),
#  ('drastik', 0.8058659217877095),
#  ('penawar', 0.8059233449477352),
#  ('kecut', 0.8061749571183533),
#  ('بيليون', 0.8062015503875969),
#  ('selesema', 0.8062015503875969),
#  ('pelik', 0.8062645011600929),
#  ('tuanku', 0.806268756252084),
#  ('fru', 0.8063063063063063),
#  ('dbp', 0.806540764624597),
#  ('arifin', 0.8066471571906354),
#  ('taksub', 0.8067278287461773),
#  ('dipertingkat', 0.8067340067340067),
#  ('wce', 0.8067632850241546),
#  ('gtr', 0.8067796610169492),
#  ('kiralah', 0.8068181818181818),
#  ('لبيه', 0.8068181818181818),
#  ('kelamin', 0.8068965517241379),
#  ('hishamuddin', 0.8069452619187758),
#  ('mercun', 0.8069541029207232),
#  ('betong', 0.8069620253164557),
#  ('familymart', 0.8070175438596491),
#  ('pengerang', 0.8070652173913043),
#  ('sazali', 0.807070707070707),
#  ('treler', 0.8070778564206269),
#  ('mohamad', 0.8070962824964011),
#  ('kapten', 0.80711743772242),
#  ('dipinggirkan', 0.8072164948453608),
#  ('serentak', 0.8072330262708973),
#  ('sewajarnya', 0.8073654390934845),
#  ('tamak', 0.8073770491803278),
#  ('lawati', 0.8075313807531381),
#  ('fauziah', 0.8075904677846425),
#  ('berkira', 0.8075949367088607),
#  ('penunggang', 0.8076009501187649),
#  ('labah', 0.8076171875),
#  ('ditubuhkan', 0.8076923076923077),
#  ('دڤنجارا', 0.8076923076923077),
#  ('setiu', 0.8076923076923077),
#  ('hsb', 0.8076923076923077),
#  ('wasilah', 0.8078078078078078),
#  ('tenis', 0.8078859060402684),
#  ('firaun', 0.8079268292682927),
#  ('inflasi', 0.8079390537289495),
#  ('lumpuh', 0.8079470198675497),
#  ('dihimpit', 0.8080465341735337),
#  ('foto', 0.808070167037773),
#  ('barulah', 0.8080808080808081),
#  ('klia', 0.8081216320246344),
#  ('biawak', 0.8081659105638367),
#  ('negaraku', 0.8082397003745319),
#  ('rohani', 0.8083097261567517),
#  ('oldtown', 0.8083623693379791),
#  ('dipotong', 0.8084183119982643),
#  ('halep', 0.808446455505279),
#  ('misai', 0.8085808580858086),
#  ('karya', 0.8086823855755895),
#  ('petronas', 0.808708296308264),
#  ('kian', 0.808792924037461),
#  ('azhan', 0.8087962962962963),
#  ('ekor', 0.8088165959453089),
#  ('zynakal', 0.8088397790055248),
#  ('mengantuk', 0.8089385474860336),
#  ('berkhasiat', 0.8090383961943595),
#  ('perarakan', 0.809042236763831),
#  ('hasnul', 0.8090737240075614),
#  ('dto', 0.8091106290672451),
#  ('bersih', 0.8091282051282052),
#  ('bayangkan', 0.8092605390463027),
#  ('singhealth', 0.8092643051771117),
#  ('selidik', 0.8094059405940595),
#  ('zahiril', 0.8095238095238095),
#  ('takziah', 0.8095755182625863),
#  ('kpn', 0.8096585549896246),
#  ('tht', 0.8096676737160121),
#  ('semporna', 0.8097808828199429),
#  ('rmaf', 0.8098039215686275),
#  ('janda', 0.8098090602770498),
#  ('diperlihatkan', 0.8098620977852069),
#  ('lantang', 0.81),
#  ('iks', 0.8100172711571675),
#  ('kagum', 0.8100854005693371),
#  ('gementar', 0.8101673101673101),
#  ('fujifilm', 0.8102022058823529),
#  ('penyudah', 0.8104395604395604),
#  ('kerani', 0.8105095541401274),
#  ('zahari', 0.8105263157894737),
#  ('frasa', 0.8106995884773662),
#  ('cdm', 0.8108108108108109),
#  ('megamall', 0.8108108108108109),
#  ('intipan', 0.8108108108108109),
#  ('ini', 0.8108280588091892),
#  ('politeknik', 0.8108352144469526),
#  ('arqam', 0.8109028960817717),
#  ('sesb', 0.8110047846889952),
#  ('maips', 0.8111533586818758),
#  ('umno', 0.8112534299873039),
#  ('kemaafan', 0.8113207547169812),
#  ('cavani', 0.8113207547169812),
#  ('perakaunan', 0.8113207547169812),
#  ('airpods', 0.8113207547169812),
#  ('pendedahan', 0.8113238692637834),
#  ('rasulullah', 0.8113380067052728),
#  ('muak', 0.8114285714285714),
#  ('rahnu', 0.8114478114478114),
#  ('دڤرچايا', 0.8114754098360656),
#  ('azeez', 0.8115175097276265),
#  ('jang', 0.8115577889447236),
#  ('hisyam', 0.8117001828153565),
#  ('liberalisme', 0.8117647058823529),
#  ('kemusnahan', 0.8119266055045872),
#  ('kehancuran', 0.8119266055045872),
#  ('ghufran', 0.8119266055045872),
#  ('akhirat', 0.8120124804992199),
#  ('liku', 0.812015503875969),
#  ('lutut', 0.8120437956204379),
#  ('gugatan', 0.8120805369127517),
#  ('kesiannya', 0.8122270742358079),
#  ('boracay', 0.8123076923076923),
#  ('jakel', 0.8123324396782842),
#  ('lynas', 0.8123376623376624),
#  ('apec', 0.8123456790123457),
#  ('narathiwat', 0.8123711340206186),
#  ('pertembungan', 0.8123861566484517),
#  ('alkohol', 0.8123872519542995),
#  ('gimik', 0.8124292622697808),
#  ('cerpen', 0.8125),
#  ('rol', 0.8125),
#  ('gbs', 0.8125),
#  ('yakeb', 0.8127853881278538),
#  ('penyelia', 0.8129770992366412),
#  ('pandir', 0.812987012987013),
#  ('puluhan', 0.8131401448913315),
#  ('mtuc', 0.8131539611360239),
#  ('hatrik', 0.8131625441696113),
#  ('caj', 0.8132877590258492),
#  ('jutaan', 0.8133180252583238),
#  ('terbakar', 0.813319493006993),
#  ('dollah', 0.8134146341463414),
#  ('sekumpulan', 0.8135226921889472),
#  ('gebeng', 0.8136200716845878),
#  ('delima', 0.8136246786632391),
#  ('curiga', 0.8136574074074074),
#  ('chye', 0.8136645962732919),
#  ('hololens', 0.8136986301369863),
#  ('demak', 0.8137472283813747),
#  ('pentingnya', 0.813778256189451),
#  ('kedoktoran', 0.8138461538461539),
#  ('penuntut', 0.8138796710431395),
#  ('sekitar', 0.8139783330829452),
#  ('perempuannya', 0.8141592920353983),
#  ('tronoh', 0.81421647819063),
#  ('spm', 0.8142274160638101),
#  ('sentosa', 0.8142340168878166),
#  ('rafiena', 0.8143350604490501),
#  ('dipermudahkan', 0.8143776824034334),
#  ...]

# %%
print(word_counts['vjc'])
print(word_1_grams['vjc'])
# Out:
# 30
# 60

# %%
with open('words_ms.txt', encoding='utf8') as f:
    ms_words = set(w.casefold() for w in set(words(f.read())))

# %%
# with open('words_ms.txt', 'wt', encoding='utf8') as f:
#     for word in sorted(ms_words):
#         f.write(word + '\n')

# %%
from bhanot_dictionary import definitions

# %%
for word in definitions:
    ms_words.add(word.casefold())

# %%
len(ms_words)
# Out:
# 49651

# %%
with open('words_en.txt', encoding='utf8') as f:
    eng_words = set(w.casefold() for w in set(words(f.read())))

# %%
len(eng_words)
# Out:
# 41120

# %%
eng_words_large = set()
with open('american-english-insane.big.txt', 'rt' ,encoding='utf8') as f:
    for word in words(f.read()):
        eng_words_large.add(word.casefold())
        eng_words_large.add(unidecode(word).casefold())
with open('british-english-insane.big.txt', 'rt' ,encoding='utf8') as f:
    for word in words(f.read()):
        eng_words_large.add(word.casefold())
        eng_words_large.add(unidecode(word).casefold())
with open('canadian-english-insane.big.txt', 'rt' ,encoding='utf8') as f:
    for word in words(f.read()):
        eng_words_large.add(word.casefold())
        eng_words_large.add(unidecode(word).casefold())

# %%
len(eng_words_large)
# Out:
# 497577

# %%
eng_words_small = set()
with open('english1k.txt', 'rt' ,encoding='utf8') as f:
    for word in words(f.read()):
        eng_words_small.add(word.casefold())
        eng_words_small.add(unidecode(word).casefold())

# %%
len(eng_words_small)
# Out:
# 1017

# %%
len(word_1_grams)
# Out:
# 77707

# %%
len([(word, count) for word, count in word_1_grams.most_common() if (word in ms_words or word not in eng_words) and len(word) > 1])
# Out:
# 57434

# %%
len(word_counts)
# Out:
# 96664

# %%
len([(word, count) for word, count in word_counts.most_common() if (word in ms_words or word not in eng_words) and len(word) > 1])
# Out:
# 76032

# %%
[(word, count) for word, count in word_counts.most_common()[:100] if (word in ms_words or word not in eng_words) and len(word) > 1]
# Out:
# [('rm', 1874016),
#  ('di', 1178209),
#  ('sqm', 1022913),
#  ('sqft', 1022892),
#  ('malaysia', 919802),
#  ('yang', 659794),
#  ('ini', 635270),
#  ('dengan', 508396),
#  ('dan', 462913),
#  ('untuk', 458248),
#  ('ke', 432370),
#  ('berita', 427828),
#  ('tak', 414164),
#  ('dalam', 389925),
#  ('najib', 385717),
#  ('anak', 362569),
#  ('tidak', 354724),
#  ('mahathir', 339233),
#  ('dunia', 326064),
#  ('umno', 316934),
#  ('tahun', 298081),
#  ('sukan', 292616),
#  ('negara', 291113),
#  ('jadi', 275003),
#  ('buat', 268337),
#  ('nasional', 261815),
#  ('saya', 261464),
#  ('rtb', 261208),
#  ('dr', 242053),
#  ('terkini', 239025),
#  ('hari', 232002),
#  ('akan', 225498),
#  ('johor', 215602),
#  ('pada', 213014),
#  ('anwar', 211300),
#  ('lagi', 209326),
#  ('lalu', 206732),
#  ('kl', 202656),
#  ('kami', 200022),
#  ('jam', 198049),
#  ('lebih', 196917),
#  ('boleh', 196523),
#  ('isu', 196461),
#  ('utama', 195099),
#  ('nak', 191906),
#  ('orang', 191204),
#  ('korang', 186482),
#  ('raja', 184775),
#  ('anda', 183868),
#  ('pru', 182380),
#  ('hiburan', 182349),
#  ('ada', 181250),
#  ('lelaki', 179276),
#  ('wanita', 178762),
#  ('perlu', 178241),
#  ('dari', 176530),
#  ('leo', 176261)]

# %%
[(word, count) for word, count in word_1_grams.most_common()[:100] if (word in ms_words or word not in eng_words) and len(word) > 1]
# Out:
# [('di', 2276706),
#  ('yang', 1273597),
#  ('malaysia', 1026458),
#  ('dengan', 970989),
#  ('untuk', 888952),
#  ('dan', 886084),
#  ('ini', 783483),
#  ('ke', 757577),
#  ('dalam', 738041),
#  ('tak', 706016),
#  ('rm', 658126),
#  ('tidak', 643949),
#  ('jadi', 512983),
#  ('anak', 509116),
#  ('buat', 498053),
#  ('akan', 430866),
#  ('najib', 423704),
#  ('mahathir', 398924),
#  ('pada', 390717),
#  ('umno', 390672),
#  ('boleh', 365123),
#  ('saya', 345137),
#  ('hari', 343108),
#  ('perlu', 342857),
#  ('tahun', 332213),
#  ('nak', 331671),
#  ('dr', 326718),
#  ('dari', 326464),
#  ('anda', 325273),
#  ('kepada', 317330),
#  ('korang', 315428),
#  ('lebih', 309124),
#  ('ada', 304873),
#  ('dunia', 301223),
#  ('negara', 299454),
#  ('orang', 298827),
#  ('wanita', 267419),
#  ('raya', 264462),
#  ('rtb', 260748),
#  ('lagi', 256625),
#  ('bakal', 255744),
#  ('lelaki', 253324),
#  ('kini', 247105),
#  ('bukan', 244913),
#  ('anwar', 243647),
#  ('petra', 237672),
#  ('mahu', 231719),
#  ('rumah', 231077),
#  ('kongsi', 226476),
#  ('johor', 222524),
#  ('dua', 222317),
#  ('isu', 214441),
#  ('baru', 213537),
#  ('selepas', 212335),
#  ('lalu', 211968),
#  ('rakyat', 211718),
#  ('kami', 209092),
#  ('raja', 207908)]
